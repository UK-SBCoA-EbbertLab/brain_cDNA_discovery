# %%
## Import Libraries
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import openpyxl

pd.set_option("max_colwidth", None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
'''
function name: parse_df_columns

purpose: parsing the last aggregate column of the gtf/gff3 into useful columns and cleaning non-relevant columns

input: dataframe containining "raw" gtf/gff

output: dataframe containing gtf with useful columns ["gene_id", "transcript_id", etc...]
'''

def parse_df_columns(df, is_ref=True):

    if is_ref:

        ## Get gene ids
        df["gene_id"] = df["other"].str.split("source_gene=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get gene names
        df["gene_name"] = df["other"].str.split("source_gene_common_name=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Only keep relevant
        df = df[["chr", "gene_id", "gene_name"]].copy()

        ## Drop duplicates
        df.drop_duplicates(inplace=True)
        

    else:

        ## Get CHM gene ids
        df["gene_id"] = df["other"].str.split('";', expand=True)[0].str.extract("([^ \"]*$)", expand=True)

        ## Drop "other" column
        df = df[["chr", "gene_id"]].copy()
        
    for col in df.columns:
        df.loc[df[col].isnull(), col] = np.NaN
        

    return df

# %%
'''
function name: calculate_cpm

purpose: Calculate CPM for the each sample given

input: Counts dataset

output: Counts dataset with CPM columns as well
'''

def calculate_cpm(df):

    ## Loop through counts columns to calculate CPM and add to the dataframe
    for col in ["total_counts"]:
        
        df[col] = round(df[col], 2)
        cpm_name = col.replace("_counts", "_CPM")
        df[cpm_name] = round(((df[col]/(df[col].sum())) * 1000000), 2)
    
    return df

# %%
## Import transcripts
df_transcripts = pd.read_csv("../../data/raw/merged_uky_cshl_GRCh38-107_discovery/bambu_discovery/counts_transcript.txt",
        sep="\t", low_memory=False, header=0)

# %%
## Import Genes
df_genes = pd.read_csv("../../data/raw/merged_uky_cshl_GRCh38-107_discovery/bambu_discovery/counts_gene.txt",
        sep="\t", low_memory=False, header=0)

# %%
## Get total counts for genes and transcripts
df_genes["total_counts"] = df_genes[df_genes.columns[1:]].sum(axis=1)
df_transcripts["total_counts"] = df_transcripts[df_transcripts.columns[2:]].sum(axis=1)

# %%
## Get average counts for genes and transcripts
df_genes["average_counts"] = df_genes["total_counts"]/4
df_transcripts["average_counts"] = df_transcripts["total_counts"]/4

# %%
## Only keep genes and transcripts with more than 0 counts
df_genes = df_genes.loc[df_genes["total_counts"] > 0].copy()
df_transcripts = df_transcripts.loc[df_transcripts["total_counts"] > 0].copy()

# %%
## Calculate percentile
df_genes['percentile'] = df_genes["total_counts"].rank(pct=True)

# %%
## Calculate Rank
df_genes['rank'] = df_genes["total_counts"].rank(ascending=False)

# %%
## See rank for TMEM106B
## Respectively: ENSG00000106460
df_genes.loc[df_genes.index.str.contains("ENSG00000106460")]
# Out:
#                  cshl_356_uky_mapped_filtered_sorted  \
# ENSG00000106460                                 3199
#
#                  cshl_1271_uky_mapped_filtered_sorted  \
# ENSG00000106460                                  3660
#
#                  cshl_1291_uky_mapped_filtered_sorted  \
# ENSG00000106460                                  3156
#
#                  cshl_1304_uky_mapped_filtered_sorted  total_counts  \
# ENSG00000106460                                  3893         10709
#
#                  average_counts  percentile    rank
# ENSG00000106460         2677.25    0.938467  3175.0

# %%
## See rank for Clu
## Respectively: ENSG00000120885
df_genes.loc[df_genes.index.str.contains("ENSG00000120885")]
# Out:
#                  cshl_356_uky_mapped_filtered_sorted  \
# ENSG00000120885                               233810
#
#                  cshl_1271_uky_mapped_filtered_sorted  \
# ENSG00000120885                                676440
#
#                  cshl_1291_uky_mapped_filtered_sorted  \
# ENSG00000120885                                286008
#
#                  cshl_1304_uky_mapped_filtered_sorted  total_counts  \
# ENSG00000120885                                507508       1469956
#
#                  average_counts  percentile  rank
# ENSG00000120885        367489.0    0.999806  11.0

# %%
## Get total counts for all genes with more than 0 counts
total_counts = df_genes["total_counts"]

# %%
## Get log total counts
log_total_counts = np.log10(df_genes["total_counts"])

# %%
print("TMEM106B Log Expression:", log_total_counts["ENSG00000106460"])
print("Clu Log Expression:", log_total_counts["ENSG00000120885"])
# Out:
# TMEM106B Log Expression: 4.0297489185668365
# Clu Log Expression: 6.16730433526301

# %%
## Use ggplot colors
ggplot2_colors = ["#F8766D", "#CD9600", "#7CAE00", "#00BE67", "#00BFC4", "#00A9FF", "#C77CFF", "#FF61CC"]

# %%
## Create log plot

fig, ax = plt.subplots(figsize = (6,4))


log_total_counts.plot(kind = "hist", density = True, bins = 100, color="#F8766D", alpha=0.5) # change density to true, because KDE uses density


log_total_counts.plot(kind = "kde", color="#CD9600", alpha=1)

ax.set_xlabel("Log10 Total Counts")


ax.set_title("Histogram of Total Read Counts per Gene")

ax.axvline(4.02, alpha=1, ymax = 0.40, linestyle = ":", color="#7CAE00")
ax.axvline(6.16, alpha=1, ymax = 0.60, linestyle = ":", color="#00BE67")


ax.text(4.02 - 1.5, 0.29, "TMEM106B", size = 12, alpha = 1, color="#7CAE00")
ax.text(6.16 - 0.5, 0.42, "Clu", size = 12, alpha = 1, color="#00BE67")



plt.show()

# %%
## Import extended annotation
gtf = pd.read_csv("../../data/raw/merged_uky_cshl_CHM13_discovery/bambu_discovery/extended_annotations.gtf",
        sep="\t", names=["chr", "source", "type", "start", 
                               "end", "dot_1", "strand", "dot_2", "other"], low_memory=False, header=0)

# %%
## Parse through it
gtf = parse_df_columns(gtf, is_ref=False)

# %%
## Get gene ids for mitochondrial genes
gtf_mito_ids = gtf.loc[gtf["chr"] == "chrM"]["gene_id"]

# %%
## Select only nuclear genes
df_genes_nuclear = df_genes.loc[~df_genes.index.isin(gtf_mito_ids)]

# %%
## Total counts for nuclear genes
total_counts_nuclear = df_genes_nuclear["total_counts"]

# %%
## Make graph for nuclear genes
fig, ax = plt.subplots(figsize = (6,4))

total_counts_nuclear.plot(kind = "hist", density = True, bins = 100, color="#F8766D", alpha=0.5) # change density to true, because KDE uses density

ax.set_xlabel("Total Counts")

ax.set_title("Histogram of Total Read Counts per Gene (Nuclear Only)\n")

ax.axvline(10432, alpha=1, ymax = 0.8, linestyle = ":", color="#7CAE00")
ax.axvline(1469956, alpha=1, ymax = 0.3, linestyle = ":", color="#00BE67")

ax.text(10432 - 1000000, 0.0000031, "TMEM106B", fontsize = 12, alpha = 1, color="#7CAE00")
ax.text(1469956 - 600000, 0.0000013, "Clu", fontsize = 12, alpha = 1, color="#00BE67")


plt.show()

# %% [markdown]
# #####################################################################################################

# %%
df_transcripts.head()
# Out:
#   TXNAME           GENEID  cshl_356_uky_mapped_filtered_sorted  \
# 0   tx.1  ENSG00000078808                           638.547019
# 1   tx.2  ENSG00000008130                            86.895137
# 2   tx.3        gene.4578                            28.000000
# 3   tx.4  ENSG00000116663                            89.692718
# 4   tx.5        gene.5343                            45.000000
#
#    cshl_1271_uky_mapped_filtered_sorted  cshl_1291_uky_mapped_filtered_sorted  \
# 0                            545.271793                            570.311659
# 1                            135.226654                            157.979474
# 2                             69.000000                            162.000000
# 3                             71.295613                             43.156208
# 4                             28.000000                             51.000000
#
#    cshl_1304_uky_mapped_filtered_sorted  total_counts  average_counts
# 0                            918.306555   2672.437026      668.109257
# 1                             89.532209    469.633474      117.408369
# 2                             67.000000    326.000000       81.500000
# 3                            154.145707    358.290246       89.572562
# 4                             26.000000    150.000000       37.500000

# %%
df_transcripts.columns = ["TXNAME", "GENEID", "356_counts", "1271_counts", "1291_counts", "1304_counts",
                          "total_counts", "average_counts"]

# %%
## Look at HAMP expression
df_transcripts.loc[df_transcripts["GENEID"].str.contains("ENSG00000106460")]
# Out:
#                 TXNAME           GENEID   356_counts  1271_counts  \
# 33578  ENST00000396667  ENSG00000106460   129.998777   110.320334
# 33579  ENST00000396668  ENSG00000106460  3050.279867  3541.603282
# 44927  ENST00000420833  ENSG00000106460     2.021825     4.036501
# 58264  ENST00000442107  ENSG00000106460    11.667589     0.000000
# 59685  ENST00000444443  ENSG00000106460     5.031943     3.039883
# 65426  ENST00000453686  ENSG00000106460     0.000000     0.000000
# 95257  ENST00000492762  ENSG00000106460     0.000000     1.000000
#
#        1291_counts  1304_counts  total_counts  average_counts
# 33578    91.758966    13.212255    345.290331       86.322583
# 33579  3057.161746  3850.766542  13499.811437     3374.952859
# 44927     5.079288     7.020131     18.157745        4.539436
# 58264     0.000000    21.000000     32.667589        8.166897
# 59685     0.000000     1.001072      9.072898        2.268225
# 65426     2.000000     0.000000      2.000000        0.500000
# 95257     0.000000     0.000000      1.000000        0.250000

# %%
## Look at SLC40A1 expression
df_transcripts.loc[df_transcripts["GENEID"].str.contains("ENSG00000120885")]
# Out:
#                  TXNAME           GENEID     356_counts    1271_counts  \
# 10496   ENST00000316403  ENSG00000120885  223055.442365  664536.249545
# 36529   ENST00000405140  ENSG00000120885    7675.128074    7953.287765
# 114089  ENST00000518050  ENSG00000120885      13.802297     359.023247
# 115417  ENST00000519472  ENSG00000120885      68.762757     192.797114
# 115674  ENST00000519742  ENSG00000120885       6.074552       3.088573
# 116376  ENST00000520491  ENSG00000120885       0.000000       3.022228
# 116661  ENST00000520796  ENSG00000120885      38.439670      54.631350
# 117587  ENST00000521770  ENSG00000120885     111.668213     354.391784
# 117896  ENST00000522098  ENSG00000120885      24.155645     123.511552
# 118026  ENST00000522238  ENSG00000120885     194.019888      30.003836
# 118084  ENST00000522299  ENSG00000120885     168.320941    1267.786800
# 118189  ENST00000522413  ENSG00000120885      10.158099      38.256630
# 118270  ENST00000522502  ENSG00000120885       6.927502      10.003349
# 119107  ENST00000523396  ENSG00000120885       6.613172       5.110760
# 119205  ENST00000523500  ENSG00000120885    2288.885390    1322.989660
# 119288  ENST00000523589  ENSG00000120885      63.715544     124.534932
# 147842  ENST00000560566  ENSG00000120885      77.885891      61.310874
#
#           1291_counts    1304_counts  total_counts  average_counts
# 10496   271582.431250  495147.812519  1.654322e+06   413580.483920
# 36529    10147.150709    9591.079185  3.536665e+04     8841.661433
# 114089     765.516726      28.862893  1.167205e+03      291.801291
# 115417      91.136672     243.879490  5.965760e+02      149.144008
# 115674       0.000000      12.167221  2.133035e+01        5.332587
# 116376       3.050670       3.094123  9.167021e+00        2.291755
# 116661      31.362227      65.707205  1.901405e+02       47.535113
# 117587     273.476503     242.009696  9.815462e+02      245.386549
# 117896      81.502678      55.309423  2.844793e+02       71.119825
# 118026     110.043076     107.013082  4.410799e+02      110.269971
# 118084     722.143349     577.985594  2.736237e+03      684.059171
# 118189      51.746061      22.292759  1.224535e+02       30.613387
# 118270       5.010400      15.016964  3.695821e+01        9.239554
# 119107       2.841611      11.440893  2.600644e+01        6.501609
# 119205    1986.454600    1155.994850  6.754324e+03     1688.581125
# 119288      65.967205     138.312029  3.925297e+02       98.132428
# 147842      88.166263      90.022073  3.173851e+02       79.346275
