# %%
## Import Libraries
import pandas as pd
import numpy as np
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import seaborn as sns

## Display all rows of pandas dataframes
pd.set_option('display.max_rows', None)

# %%
'''
function name: calculate_cpm

purpose: Calculate CPM for the each sample given

input: Counts dataset

output: Counts dataset with CPM columns as well
'''

def calculate_cpm(df, is_gene=False):

    ## Set count columns if dataframe is gene counts
    if is_gene:
        count_columns = df.columns[1:].tolist()
    
    ## Set count columns if dataframe is transcript counts
    else:
        count_columns = df.columns[2:].tolist()

    ## Loop through counts columns to calculate CPM and add to the dataframe
    for col in count_columns:
        
        df[col] = round(df[col], 2)
        cpm_name = col.replace("_counts", "_CPM")
        df[cpm_name] = round(((df[col]/(df[col].sum())) * 1000000), 2)
    
    return df

# %%
'''
function name: fix_column_names

purpose: Fixing the column names, making them smaller, informative, and consistent

input: The raw counts dataframe for either genes or transcripts 

output: Same dataframe with improved column names
'''

def fix_column_names(df, is_gene=False):
    
    ## Check if this is a gene counts object
    if is_gene:
        
        ## Get count column names and create list of new column names
        count_columns = df.columns.tolist()
        list_new_names = ["gene_id"]
        
        ## gene_id comes in as index for gene counts data, make it into the first column instead
        df["gene_id"] = df.index
        cols = list(df.columns)
        cols = [cols[-1]] + cols[:-1]
        df = df[cols]
        df.reset_index(inplace=True, drop=True)
    
    ## If it is a transcript dataset
    else:
        ## Set count columns and create list of new names
        count_columns = df.columns[2:].tolist()
        list_new_names = [ "transcript_id", "gene_id"]
    
    ## Fix names one by one and add to list of new names
    for col in count_columns:
        col = col.split("_mapped")[0] + "_counts"
        list_new_names.append(col)
    
    ## Rename columns
    df.columns = list_new_names
    
    return df

# %%
'''
name: relative_transcript_abundance

purpose: calculate relative transcript abundance

input: a dataframe with a ref_gene_id column identifying the transcript gene of origin and a cov columns with 
the coverage for the transcripts.

output: the same dataframe with a relative abundance column added
'''



def relative_transcript_abundance(df):
    
    df_sums = df[["gene_id", "total_CPM"]].groupby("gene_id").sum()
    
    df_sums["total_CPM_gene"] = df_sums["total_CPM"]

    df_sums.drop(columns="total_CPM", inplace=True)
    
    merged_df = pd.merge(df, df_sums, how='inner', on="gene_id")
    
    merged_df["relative_abundance_percent"] = ((merged_df["total_CPM"]/merged_df["total_CPM_gene"]) * 100)
    
    merged_df.drop(columns="total_CPM", inplace=True)
    
    return merged_df

# %%
'''
function name: parse_df_columns

purpose: parsing the last aggregate column of the gtf/gff3 into useful columns and cleaning non-relevant columns

input: dataframe containining "raw" gtf/gff

output: dataframe containing gtf with useful columns ["gene_id", "transcript_id", etc...]
'''

def parse_df_columns(df, is_ref=True):

    if is_ref:

        ## Get gene ids
        df["gene_id"] = df["other"].str.split("source_gene=", expand=True)[1].str.split(';', expand=True)[0]

        ## Get transcript ids
        df["transcript_id"] = df["other"].str.split("source_transcript=", expand=True)[1].str.split(';', expand=True)[0]

        ## Get CHM gene_ids
        df["CHM_gene_id"] = df["other"].str.split("gene_id=", expand=True)[1].str.split(';', expand=True)[0]

        ## Get transcript ids
        df["CHM_transcript_id"] = df["other"].str.split("transcript_id=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get transcript names
        df["transcript_name"] = df["other"].str.split("source_transcript_name=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get gene names
        df["gene_name"] = df["other"].str.split("source_gene_common_name=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get start codon
        df["start_codon"] = df["other"].str.split("adj_start=", expand=True)[1].str.split(";", expand=True)[0]
        
        ## Get stop codon
        df["stop_codon"] = df["other"].str.split("adj_stop=", expand=True)[1].str.split(";", expand=True)[0]        

        ## Only keep relevant
        df = df[["chr", "start", "end", "strand", "type", "gene_id", "transcript_id", "CHM_gene_id",
                 "CHM_transcript_id", "transcript_name", "gene_name", "start_codon", "stop_codon"]].copy()

        ## Drop duplicates
        df.drop_duplicates(inplace=True)
        

    else:

        ## Get CHM gene ids
        df["gene_id"] = df["other"].str.split('";', expand=True)[0].str.extract("([^ \"]*$)", expand=True)
        
        
        df["gene_name"] = df["other"].str.split("gene_name \"", expand=True)[1].str.split('\";', expand=True)[0]


        ## Get CHM transcript ids
        #df["transcript_id"] = df["other"].str.split('transcript_id "', expand=True)[1].str.split('"', expand=True)[0]

        ## Get exon number
        #df["exon_number"] = df["other"].str.split('exon_number "', expand=True)[1].str.split('"', expand=True)[0]

        ## Label novel transcripts
        #df.loc[df["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = True
        #df.loc[~df["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = False

        ## Label novel genes
        #df.loc[df["gene_id"].str.startswith("gene."), "is_novel_gene"] = True
        #df.loc[~df["gene_id"].str.startswith("gene."), "is_novel_gene"] = False

        ## Drop "other" column
        df.drop(columns=["other", "dot_1", "dot_2"], inplace=True)

    for col in df.columns:
        df.loc[df[col].isnull(), col] = np.NaN
        

    return df

# %%
'''
function name: merge_annotations

purpose: Merge useful/relevant information from both annotations while removing repeated and irrelevant information

input: Two different GTF annotations

output: One GTF annotation containing all the relevant information
'''

def merge_annotations(ref_gtf, bambu_gtf):
    
    ## Merge the two annotations
    names_ref_gtf = ref_gtf[["transcript_id", "gene_id", "gene_name", "transcript_name"]].copy()
    merged_gtf = pd.merge(bambu_gtf, names_ref_gtf, on=['gene_id', 'transcript_id'], how='left')
    merged_gtf.drop_duplicates(inplace=True)

    ## Label novel transcripts
    merged_gtf.loc[merged_gtf["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = True
    merged_gtf.loc[~merged_gtf["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = False

    ## Label novel genes
    merged_gtf.loc[merged_gtf["gene_id"].str.startswith("gene."), "is_novel_gene"] = True
    merged_gtf.loc[~merged_gtf["gene_id"].str.startswith("gene."), "is_novel_gene"] = False

    ## Create temporary variable only containing novel transcripts
    temp = merged_gtf.loc[merged_gtf["is_novel_transcript"] == True]

    ## Annotate novel transcripts
    merged_tmp = pd.merge(temp, ref_gtf[["gene_id", "gene_name"]], on=['gene_id'], how='left')
    merged_tmp.drop_duplicates(inplace=True)
    merged_tmp["gene_name"] = merged_tmp["gene_name_y"]
    merged_tmp.drop(columns=["source", "gene_name_y", "gene_name_x"], inplace=True)

    ## Return novel transcripts to original annotation
    merged_final = pd.merge(merged_gtf, merged_tmp, on=['chr', 'type', 'start', 'end', 'strand', 'transcript_id',
                    'transcript_name', 'gene_id', 'is_novel_transcript', 'is_novel_gene', 'exon_number'], how="left")

    ## Get gene names for novel transcripts of known genes
    merged_final.gene_name_x.fillna(merged_final.gene_name_y, inplace=True)
    merged_final["gene_name"] = merged_final["gene_name_x"]
    merged_final.drop(columns =["gene_name_x", "gene_name_y"], inplace=True)
    
    ## Get start and stop codons for known transcripts and exons of protein coding genes
    ref_gtf = ref_gtf[["chr", "type", "start", "end", "strand", "transcript_id", "gene_id", "start_codon", "stop_codon"]]
    merged_final = pd.merge(merged_final, ref_gtf, on=["chr", "type", "start", "end", "strand", "transcript_id", "gene_id"], how="left")
    
    
    merged_final = merged_final[["chr", "type", "start", "end", "strand", "transcript_id", "gene_id", "gene_name", 
                    "exon_number", "transcript_name", "start_codon", "stop_codon", "is_novel_gene", "is_novel_transcript"]]


    
    return merged_final

# %%
'''
name: make_gene_and_transcript_converter

input: The CHM13 CAT/Liftoff gff annotation version 2.0

output: A dataframe with ["gene_id", "transcript_id", "gene_name", "transcript_name"] formatted in the same way as the 
bambu reference, so that we can properly assign gene and transcript names.

purpose: Creating a list that allows us to assign transcript and gene names to the bambu annotation based on the transcript
id and gene ID
'''


def make_gene_and_transcript_converter(gff):
    
    ## Change name of duplicate Ensembl IDs to CHM IDs
    gff.loc[gff["transcript_id"] == "N/A", "transcript_id"] = gff["CHM_transcript_id"]
    gff_transcripts = gff.loc[gff["type"] == "transcript"].copy()
    gff_transcripts = gff_transcripts[["transcript_id", "CHM_transcript_id"]].drop_duplicates()
    gff_transcripts = gff_transcripts[gff_transcripts['transcript_id'].duplicated() == True]
    dup_trans = gff_transcripts["transcript_id"].dropna().values.tolist()
    gff.loc[gff["transcript_id"].isin(dup_trans), "transcript_id"] = gff["transcript_id"] + "(" + gff["CHM_transcript_id"] + ")"

    ## Change name of duplicate gene ids to CHM ids
    gff.loc[gff["gene_id"] == "None", "gene_id"] = gff["CHM_gene_id"]
    gff_genes = gff.loc[gff["type"] == "transcript"].copy()
    gff_genes = gff_genes[["gene_id", "CHM_gene_id"]].drop_duplicates()
    gff_genes = gff_genes[gff_genes['gene_id'].duplicated() == True]
    dup_genes = gff_genes["gene_id"].dropna().values.tolist()
    gff.loc[gff["gene_id"].isin(dup_genes), "gene_id"] = gff["gene_id"] + "(" + gff["CHM_gene_id"] + ")"

    
    ## Fix gene names for MSTRG Genes
    gff_names = gff.loc[gff["type"] == "transcript"].copy()
    gff_names = gff_names[["gene_id", "gene_name"]].copy()
    gff_names.loc[gff_names["gene_name"].str.contains("MSTRG."), "gene_name"] = np.NaN
    gff_names.dropna(inplace=True)
    gff_names.drop_duplicates(inplace=True, subset=["gene_id"])
    gff.drop(columns="gene_name", inplace=True)
    gff = pd.merge(gff, gff_names, on="gene_id", how="left")
    gff = gff[["gene_id", "transcript_id", "gene_name", "transcript_name",
              "start", "end", "type", "start_codon", "stop_codon", "chr", "strand"]].copy()


    return gff

# %%
## Fix column names in counts matrix

grch38_counts = pd.read_csv("../../data/raw/merged_aged_stringent/bambu_discovery/counts_transcript.txt", 
                           delimiter="\t", low_memory=False, header=0)

grch38_counts = fix_column_names(grch38_counts, is_gene=False)

# %%
## Calculate total counts and fix gene id
grch38_counts["total_counts"] = grch38_counts[grch38_counts.columns[2:6].tolist()].sum(axis=1)

# %%
## Calculate CPM and drop count columns
grch38_counts = calculate_cpm(grch38_counts, is_gene=False)

grch38_counts = grch38_counts[grch38_counts.columns.drop(list(grch38_counts.filter(regex='counts')))]

# %%
## Find novel transcripts in both annotations
grch38_counts.loc[grch38_counts["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = True
grch38_counts.loc[~grch38_counts["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = False

## Find novel genes in both annotations
grch38_counts.loc[grch38_counts["gene_id"].str.startswith("gene."), "is_novel_gene"] = True
grch38_counts.loc[~grch38_counts["gene_id"].str.startswith("gene."), "is_novel_gene"] = False

# %%
## Create dataframes with either only novel genes or only novel transcripts that are not from novel genes
grch38_novel_genes = grch38_counts.loc[grch38_counts["is_novel_gene"]].copy()
grch38_novel_transcripts = grch38_counts.loc[((grch38_counts["is_novel_transcript"]) & (~grch38_counts["is_novel_gene"]))].copy()

# %%
## See how many novel genes
print("We found", grch38_novel_genes.shape[0], "novel genes in GRCh38")
# Out:
# We found 207 novel genes in GRCh38

# %%
## Filter novel genes and transcripts, total CPM > 1
grch38_novel_genes = grch38_novel_genes[(grch38_novel_genes["total_CPM"]>1)]
grch38_novel_transcripts = grch38_novel_transcripts[(grch38_novel_transcripts["total_CPM"]>1)]

# %%
## Count number of novel genes and novel transcripts in each dataframe
print("We found", grch38_novel_genes.shape[0], "novel genes in GRCh38")
print("We found", grch38_novel_transcripts.shape[0], "novel transcripts of known genes in GRCh38")
# Out:
# We found 79 novel genes in GRCh38
# We found 472 novel transcripts of known genes in GRCh38

# %%
## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
grch38_ref = pd.read_csv("../../data/raw/merged_aged_stringent/bambu_discovery/extended_annotations.gtf",
                        header=None, delimiter="\t", low_memory=False, 
                        names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"])


grch38_ref = parse_df_columns(grch38_ref, is_ref=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 7>()
#       1 ## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
#       2 grch38_ref = pd.read_csv("../../data/raw/merged_aged_stringent/bambu_discovery/extended_annotations.gtf",
#       3                         header=None, delimiter="\t", low_memory=False,
#       4                         names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"])
# ----> 7 grch38_ref = parse_df_columns(grch38_ref, is_ref=False)
#
# Input In [5], in parse_df_columns(df, is_ref)
#      47 else:
#      48
#      49     ## Get CHM gene ids
#      50     df["gene_id"] = df["other"].str.split('";', expand=True)[0].str.extract("([^ \"]*$)", expand=True)
# ---> 53     df["gene_name"] = df["other"].str.split("gene_name \"", expand=True)[1].str.split('\";', expand=True)[0]
#      56     ## Get CHM transcript ids
#      57     #df["transcript_id"] = df["other"].str.split('transcript_id "', expand=True)[1].str.split('"', expand=True)[0]
#      58
#    (...)
#      69
#      70     ## Drop "other" column
#      71     df.drop(columns=["other", "dot_1", "dot_2"], inplace=True)
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 1

# %%
## Only keep transcripts
grch38_ref = grch38_ref.loc[grch38_ref["type"] == "transcript"]

# %%
## Only keep expressed transcripts
grch38_novel_transcripts_expressed = grch38_ref.loc[grch38_ref["transcript_id"].isin(
                                                    grch38_novel_transcripts["transcript_id"])].copy()

# %%
## Import disease relevant genes
disease_relevant_genes = pd.read_csv("../../references/disease_relevant_gene_names.csv", 
                                     names=["gene_id", "gene_name"], header=0)
## Ad genes
ad_names = pd.read_csv("../../references/AD_genes.csv", sep="\t")
ad_names.dropna(inplace=True)
ad_names.drop_duplicates(inplace=True)

## Concatenate both
disease_relevant_genes = pd.concat([disease_relevant_genes, ad_names]).drop_duplicates()

# %%
## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
orig_ref = pd.read_csv("../../references/Homo_sapiens.GRCh38.107_ERCC.gtf", header=None, delimiter="\t", low_memory=False, 
                       names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"], comment="#")

# %%
## Create good reference to convert gene names
orig_ref = parse_df_columns(orig_ref, is_ref=False)
orig_ref = orig_ref.loc[orig_ref["type"]=="gene"].copy()

# %%
## Create list of novel transcripts in disease relevant genes
novel_relevant = disease_relevant_genes.merge(orig_ref[["gene_id", "gene_name"]], on=["gene_id", "gene_name"], how="inner")

# %%
## Only keep gene_ids that match, add gene names
novel_relevant = grch38_novel_transcripts_expressed.merge(novel_relevant[["gene_id", "gene_name"]], on=["gene_id"], how="inner")

# %%
## Drop any duplicates
novel_relevant.drop_duplicates(inplace=True)

# %%
## See shape
novel_relevant.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 ## See shape
# ----> 2 novel_relevant.shape
#
# NameError: name 'novel_relevant' is not defined

# %%
## Remove MT transcripts
novel_relevant = novel_relevant.loc[novel_relevant["chr"] != "MT"]

# %%
## Only keep original ensembl ID
grch38_counts_ensembl_id = grch38_counts.copy()

# %%
## Merge with medically relevant genes on gene_id and get gene names
novel_relevant_counts = pd.merge(grch38_counts_ensembl_id, novel_relevant[["gene_id", "gene_name"]], on=["gene_id"], how="inner")

# %%
## Drop any duplicates
novel_relevant_counts.drop_duplicates(inplace=True)

# %%
## See shape
novel_relevant_counts.shape
# Out:
# (449, 10)

# %%
## See number of novel transcript left
novel_relevant_counts.loc[novel_relevant_counts["is_novel_transcript"]==True].shape
# Out:
# (41, 10)

# %%
## Calculate relative transcript abundance
novel_relevant_relative_abundance = relative_transcript_abundance(novel_relevant_counts)

# %%
## Create list with med relevant genes with novel isoforms and their relative frequency
novel_relevant_words = novel_relevant_relative_abundance.loc[novel_relevant_relative_abundance["is_novel_transcript"] == True][["gene_name", "relative_abundance_percent"]]

# %%
## Drop duplicates
novel_relevant_words = novel_relevant_words.drop_duplicates()

# %%
## Sum relative abundance of all novel isoforms by gene name and round to nearest integer
novel_relevant_words = round(novel_relevant_words.groupby("gene_name")["relative_abundance_percent"].sum(), 0)

# %%
## Create a dataframe to properly store the data
novel_relevant_word_df = pd.DataFrame()
novel_relevant_word_df['word_count'] = novel_relevant_words
novel_relevant_word_df["gene_name"] = novel_relevant_words.index

# %%
## Drop index
novel_relevant_word_df.reset_index(inplace=True, drop=True)

# %%
## Print genes with novel isoforms relevant to AD
ad_names = pd.read_csv("../../references/AD_genes.csv", sep="\t")
print(novel_relevant_word_df.loc[novel_relevant_word_df["gene_name"].isin(ad_names["gene_name"])])
# Out:
# Empty DataFrame
# Columns: [word_count, gene_name]
# Index: []

# %%
## Print relative abundance for a couple other genes
print(novel_relevant_word_df.loc[novel_relevant_word_df["gene_name"].isin(["MAOB", "SLC26A1"])])
# Out:
#     word_count gene_name
# 18         9.0      MAOB
# 31        90.0   SLC26A1

# %%
novel_relevant_word_df
# Out:
#     word_count gene_name
# 0         74.0   ALDH1A1
# 1         16.0   B4GALT7
# 2         33.0      BCAN
# 3         70.0      CA5A
# 4         75.0    CAMKMT
# 5         18.0      CAST
# 6         61.0       CD4
# 7         34.0     CLIC2
# 8         24.0     CPLX2
# 9         12.0      CRBN
# 10        41.0     DGUOK
# 11        23.0      DPYD
# 12        61.0      DPYS
# 13        34.0      FGF9
# 14        14.0       IVD
# 15        39.0       KHK
# 16        63.0     KIF27
# 17         5.0      LRP4
# 18         9.0      MAOB
# 19         7.0    MAP2K4
# 20        38.0       MFF
# 21        20.0    NDUFV3
# 22        36.0     NELFA
# 23        18.0      NME5
# 24        19.0     PBRM1
# 25        56.0       PKM
# 26        47.0      POLB
# 27        11.0     PPP6C
# 28        44.0    PSENEN
# 29        75.0    RAB27B
# 30        34.0      ROM1
# 31        90.0   SLC26A1
# 32        38.0       SMS
# 33        47.0     SNTG2
# 34        71.0      TBCE
# 35        24.0      TET1
# 36         8.0      TSFM
# 37        12.0   XPNPEP3
# 38        41.0    ZNF429

# %%
## Print number of disease relevant genes with high-confidence novel isoforms
novel_relevant_word_df["gene_name"].nunique()
# Out:
# 39

# %%
## Generate word list with frequency of word being proportional to novel isoform relative abundance
word_list = ""

for i in range(len(novel_relevant_word_df)):
        
    for j in range(int(novel_relevant_word_df.iloc[i][0])):
        word_list = word_list + novel_relevant_word_df.iloc[i][1] + " "

# %%
## Generate wordcloud
word_cloud = WordCloud(collocations=False, font_step=1, background_color='white', regexp=r"\w[\w\-]+", normalize_plurals=False,
            colormap="nipy_spectral", prefer_horizontal=1, include_numbers=True, stopwords=None, random_state=1996,
                      width=20000, height=5000).generate(word_list)

# %%
## Save the in-person poster version (higher DPI) 
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('../../figures/bioinfo_presentation/word_cloud_in-person.png', dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %% [markdown]
# ###########################################################################################################################

# %%
## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
orig_ref = pd.read_csv("../../references/Homo_sapiens.GRCh38.101.gtf", header=None, delimiter="\t", low_memory=False, 
                       names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"])

# %%
## Create good reference to convert gene names
orig_ref = parse_df_columns(orig_ref, is_ref=False)
#orig_ref = orig_ref.loc[orig_ref["type"]=="gene"].copy()

# %%
orig_ref.loc[((orig_ref["gene_id"].str.contains("ENSG00000108379")) & (orig_ref["type"]=="transcript"))]
# Out:
#         chr          source        type       start         end strand  \
# 2472981  17  ensembl_havana  transcript  46762506.0  46818692.0      -
# 2472996  17          havana  transcript  46773842.0  46833033.0      -
# 2473001  17          havana  transcript  46830595.0  46833058.0      -
# 2473005  17          havana  transcript  46831405.0  46833154.0      -
#
#                  gene_id gene_name
# 2472981  ENSG00000108379      WNT3
# 2472996  ENSG00000108379      WNT3
# 2473001  ENSG00000108379      WNT3
# 2473005  ENSG00000108379      WNT3

# %%
## Only keep gene_ids that match between both
grch38_counts_with_name = grch38_counts.merge(orig_ref[["gene_id", "gene_name"]], on=["gene_id"], how="inner")

# %%
## Drop any duplicates
grch38_counts_with_name.drop_duplicates(inplace=True)

# %%
grch38_counts_with_name["gene_id"] = grch38_counts_with_name["gene_id"].str.split(".", expand=True)[0]

# %%
## Get the gene names in the counts matrix and only keep medically relevant genes
medically_relevant_counts = grch38_counts_with_name.merge(disease_relevant_genes[["gene_id", "gene_name"]], on=["gene_id", "gene_name"], how="inner")

# %%
## Delete duplicates
medically_relevant_counts.drop_duplicates(inplace=True)

# %%
## Remove all isoforms with less than 500 reads in every sample
medically_relevant_counts = medically_relevant_counts[(medically_relevant_counts["total_CPM"]>5)].copy()

# %%
## Only keep genes with more than one "highly expressed" isoforms
dup_gene_names = medically_relevant_counts.loc[medically_relevant_counts.duplicated(subset="gene_id")]

medically_relevant_counts_multiple_iso = medically_relevant_counts.loc[medically_relevant_counts["gene_id"].isin(dup_gene_names["gene_id"])].copy()

# %%
## How many medically relevant isoforms with more than one highly expressed isoforms in one gene
medically_relevant_counts_multiple_iso.shape
# Out:
# (2367, 10)

# %%
## How many highly expressed isoforms are there for each gene?
df_numbers = medically_relevant_counts_multiple_iso["gene_id"].value_counts()

# %%
## How many medically relevant genes have more than one highly expressed isoform?
medically_relevant_counts_multiple_iso["gene_id"].nunique()
# Out:
# 913

# %%
## Display their names
medically_relevant_counts_multiple_iso["gene_name"].unique()
# Out:
# array(['BCAN', 'LRP4', 'ROM1', 'PKM', 'MAP2K4', 'ZNF429', 'PSENEN', 'KHK',
#        'DGUOK', 'MFF', 'NDUFV3', 'CRBN', 'NELFA', 'CAST', 'CPLX2', 'POLB',
#        'ALDH1A1', 'PPP6C', 'MT-TQ', 'MAOB', 'MT-TS1', 'SMS', 'CD74',
#        'ERCC1', 'GABRA1', 'RB1CC1', 'RNASET2', 'GOPC', 'DCN', 'KIF22',
#        'KCNAB2', 'REEP1', 'KEAP1', 'ASNS', 'ALDH3A2', 'MRPS34', 'SLC25A3',
#        'CTSA', 'ACTN1', 'DLG3', 'MAP2', 'LAMP2', 'EPB41L1', 'SPG21',
#        'GNPTG', 'GOLGA3', 'COMT', 'TECR', 'MIF', 'XBP1', 'SYNGR1', 'ACO2',
#        'HSP90AA1', 'SUPT16H', 'APEX1', 'PABPN1', 'ARHGAP5', 'NFKBIA',
#        'EEF1A2', 'WDR13', 'FMR1', 'PQBP1', 'HUWE1', 'ARHGEF7', 'USB1',
#        'FDFT1', 'GDAP1', 'EIF3E', 'NEFM', 'PNPLA6', 'FCGRT', 'FKBP8',
#        'PON2', 'CLIP2', 'AK1', 'SETX', 'VIM', 'SLC25A39', 'GIT1', 'WNT3',
#        'GOSR2', 'DDX5', 'KAT2A', 'RANGRF', 'WFS1', 'LDHA', 'CRYAB',
#        'PPFIBP1', 'TPI1', 'C12orf57', 'BCL6', 'NCK2', 'MPV17', 'RPS15',
#        'GGCX', 'RPL22', 'MFN2', 'PRDM2', 'HMGCL', 'CTSD', 'EEF1B2',
#        'B4GALT6', 'SGK1', 'SPP1', 'MXI1', 'RNF170', 'TARDBP', 'MAPK8IP1',
#        'PEPD', 'DST', 'CDKN1A', 'ATXN1', 'BBS2', 'MBOAT7', 'C3', 'MAX',
#        'RALY', 'UROD', 'KLC1', 'ELK1', 'COX7C', 'PIN1', 'PNKD', 'HSPB1',
#        'TST', 'EMC4', 'CALU', 'DMXL2', 'MEGF8', 'HBA2', 'PCCB', 'RAF1',
#        'NDUFA2', 'LDLR', 'ACTN4', 'NDUFA10', 'ZNF331', 'ARHGEF9', 'GFAP',
#        'ATP6V1E1', 'COX4I1', 'FUS', 'EFR3A', 'IMMT', 'SERPINF1', 'SNAP25',
#        'CHL1', 'SORT1', 'LPIN1', 'ACP2', 'FOLH1', 'KMT2E', 'DYSF',
#        'RCBTB1', 'GPNMB', 'CCM2', 'KAT7', 'BIN1', 'LRRC8A', 'TUBB2B',
#        'FAM8A1', 'FXYD6', 'ADCY3', 'PREPL', 'LRPPRC', 'SHTN1', 'WDR12',
#        'ITGAV', 'TMPO', 'CCND2', 'HEXB', 'CSDE1', 'MAN2A1', 'B9D1',
#        'MSMO1', 'PALLD', 'LPIN2', 'SLC7A5', 'SREBF1', 'TTC19', 'SPG11',
#        'PHF3', 'MTUS1', 'DNAJB6', 'TRIM37', 'CLCN7', 'MAPT', 'KANSL1',
#        'NLRP1', 'PITPNM3', 'GNAO1', 'CSNK2A2', 'SEC23B', 'TYROBP',
#        'SCN1B', 'ITCH', 'PAFAH1B3', 'MAP2K2', 'OPTN', 'SMARCB1', 'EP300',
#        'BRD4', 'PRKCG', 'DNAJC6', 'ATP2B3', 'FOXRED1', 'SIAE', 'KCNT1',
#        'CD81', 'TP53BP1', 'AKT3', 'KIF1B', 'EHBP1', 'MCOLN1', 'ATF2',
#        'RAB3GAP1', 'ORC4', 'ARID4B', 'ECE1', 'YWHAE', 'ANK2', 'CUL3',
#        'GLRB', 'RAP1GDS1', 'THRA', 'SMARCE1', 'NNT', 'MTRR', 'ADD1',
#        'OLFM2', 'RIMS1', 'SDHA', 'MAP3K13', 'MGLL', 'RAB7A', 'FBXW11',
#        'SLC1A3', 'SHOC2', 'NRXN2', 'MGST2', 'LARS2', 'RHOA', 'GNAS',
#        'NSMF', 'ADAM22', 'EIF4H', 'LZTS1', 'HNRNPH3', 'CPEB3', 'DAXX',
#        'GNAI2', 'FBXO7', 'DNM1L', 'PEX5', 'SUOX', 'DIABLO', 'TCF12',
#        'ETFA', 'TPM1', 'MFGE8', 'ABAT', 'FTO', 'SPG7', 'NCOR1', 'G6PC3',
#        'CLTC', 'GNAL', 'DTNA', 'DYM', 'SH3GL1', 'SOD1', 'TPM3', 'ACP1',
#        'CALM2', 'RPS27A', 'SLC4A10', 'UBR3', 'UNC80', 'FTH1', 'NICN1',
#        'RASA1', 'MEGF10', 'ARHGAP26', 'NHP2', 'QKI', 'NLGN4X', 'NONO',
#        'RSPO2', 'NDUFB9', 'NTRK2', 'CIZ1', 'GLUD1', 'SERPING1', 'BSCL2',
#        'CNKSR2', 'DLAT', 'PTS', 'USP15', 'THRB', 'ANK3', 'NRXN3', 'QDPR',
#        'NBAS', 'ATP8A2', 'CACNB2', 'FLT1', 'PPM1B', 'NADK2', 'GPD1L',
#        'TIA1', 'LIPA', 'HNRNPU', 'RANBP2', 'SCN3A', 'SCN2A', 'JAZF1',
#        'MSI2', 'UCHL1', 'LY96', 'ERCC3', 'TMEM237', 'SLC24A2', 'KIF5A',
#        'ADK', 'TSPAN7', 'UQCRB', 'KAT6B', 'AIFM1', 'SLC6A1', 'HMGCR',
#        'ASTN2', 'OBSL1', 'SLC12A6', 'IFNGR2', 'ALDH4A1', 'CBFB', 'ABR',
#        'CALM3', 'ST6GALNAC6', 'TNNT1', 'ETHE1', 'SYNGAP1', 'NCKIPSD',
#        'AZIN2', 'BOLA3', 'CHN1', 'ATP1A1', 'IGFBP7', 'TGFBR2', 'TUBA1A',
#        'SERPINI1', 'SYN1', 'GYG1', 'PPP1CB', 'ETNPPL', 'NDUFAF2',
#        'NDUFS4', 'NPM1', 'HSPA9', 'RAD21', 'COX6C', 'PDP1', 'CFL2',
#        'PHKB', 'GABRB3', 'PCBD1', 'SCN3B', 'ILK', 'TPP1', 'COG1',
#        'ZNF592', 'NAB2', 'STAT6', 'HERPUD1', 'COQ4', 'CRK', 'STIM1',
#        'PRRT2', 'VKORC1', 'TPM4', 'UNC119', 'KMT2D', 'SPINT2', 'SDHAF2',
#        'KCND3', 'SMARCA2', 'KCNAB1', 'CTNNA1', 'DLG4', 'POLR1D', 'RFXANK',
#        'HCN1', 'MECP2', 'SCN1A', 'BTD', 'AUH', 'CAMTA1', 'ZEB2', 'CHST11',
#        'NFU1', 'CHCHD7', 'REPS2', 'HINT1', 'TMEM126A', 'MAP6', 'PRPF8',
#        'GAP43', 'GRM5', 'CERS6', 'BCR', 'ST3GAL5', 'FASN', 'GFRA2',
#        'GPS1', 'FIP1L1', 'MAP2K1', 'USP8', 'SLCO1A2', 'KIAA0232', 'SYNPO',
#        'BCL2L1', 'SEC23A', 'ETFDH', 'AFF1', 'SNAPC5', 'RNASEH2C',
#        'ATP2A2', 'SEZ6L2', 'DAG1', 'NDUFA11', 'ZHX3', 'ETFB', 'EEF1A1',
#        'B4GALT2', 'SPTBN2', 'SNCB', 'LGI4', 'CTSF', 'HCFC1', 'GPD2',
#        'MRPL48', 'MRPS22', 'MAPK10', 'HDLBP', 'RPL38', 'TNS3', 'KRT17',
#        'GLUL', 'RABL6', 'MLC1', 'COMMD1', 'RPS14', 'MEN1', 'NSD2',
#        'BANF1', 'TMEM70', 'NAGPA', 'PMP22', 'STX16', 'PFKM', 'MED25',
#        'PRCP', 'CADPS2', 'PDE4DIP', 'NDUFS8', 'OSBPL2', 'FAM20C', 'FUZ',
#        'RCAN1', 'BTBD9', 'ASAH1', 'SPECC1L', 'PPP2R2C', 'ZMYM3', 'CD55',
#        'TNIP1', 'ST8SIA5', 'GPHN', 'TUBB3', 'CDC42', 'CD200', 'ABCD3',
#        'RPL5', 'TFE3', 'WNK1', 'TUBA8', 'KCNA2', 'CLU', 'CALR', 'SLC9A9',
#        'LLGL1', 'NSD3', 'MSRA', 'NTRK3', 'CAPN3', 'CRAT', 'GRHPR', 'BBS1',
#        'ABL1', 'A2M', 'PABPC1', 'TALDO1', 'MCFD2', 'ARID1B', 'B4GALT3',
#        'SLC25A22', 'KIF1A', 'NQO1', 'PIK3R1', 'HBA1', 'FMN1', 'PINK1',
#        'PRKCB', 'SLC14A1', 'CRTC1', 'CD151', 'SET', 'ROGDI', 'SMC1A',
#        'NDUFV1', 'PLEC', 'ACADVL', 'PPP3CA', 'HIF1A', 'TCOF1', 'NDRG1',
#        'SNRNP200', 'FN1', 'EIF4A2', 'PSEN1', 'SCN4B', 'CEP57', 'PRKRA',
#        'FGFR1', 'CRELD1', 'PEG3', 'ATP13A2', 'NDUFAF3', 'DKK3', 'JMJD1C',
#        'NDUFA12', 'COL4A5', 'ATP2C1', 'COA5', 'GALNT9', 'RPL35A',
#        'ANKS1B', 'NOP56', 'NDUFB1', 'PEX26', 'SV2B', 'CHD3', 'DDX41',
#        'SULT4A1', 'EWSR1', 'NRXN1', 'FBXW4', 'GLRX5', 'CADM1', 'BGN',
#        'TBK1', 'OPCML', 'DPP6', 'CSGALNACT1', 'BRWD1', 'BSG', 'PCLO',
#        'SPTBN1', 'NF2', 'KTN1', 'HBB', 'PIP5K1C', 'WASF3', 'SF3B1',
#        'CSMD1', 'GABRA5', 'NPAS2', 'BCL11A', 'SLC44A2', 'GRB10', 'ZBTB16',
#        'UBA1', 'LIMK1', 'ZFP36L1', 'FGFR2', 'DNAJB2', 'PPP2R2B',
#        'LRRFIP2', 'SNCA', 'AGTPBP1', 'EZR', 'SOD2', 'RAD51C', 'NIPA1',
#        'EBAG9', 'ELAC2', 'MEF2A', 'SHANK2', 'PARK7', 'DYRK1A', 'DTNBP1',
#        'USP9Y', 'ABHD12', 'SRSF3', 'NUDT1', 'USP1', 'UBE3B', 'MEF2C',
#        'ACSL4', 'IDS', 'B4GALNT1', 'DNM1', 'DPM3', 'ATP2B4', 'MPC1',
#        'FHIT', 'SMPD1', 'NR3C2', 'FUT8', 'EIF4G1', 'SMAD4', 'CTNNA2',
#        'DICER1', 'EXT2', 'TRIO', 'AFDN', 'GAD1', 'KCNQ2', 'LARP7',
#        'DROSHA', 'POMGNT2', 'RPS10', 'RPL10', 'USP7', 'BCAP31', 'CTSB',
#        'PRICKLE1', 'RNF6', 'NNAT', 'MYLK', 'UBE2A', 'SNRPN', 'DDIT3',
#        'APP', 'ABI1', 'SYNE1', 'PSAT1', 'RPL36', 'CLCN3', 'CNTN1', 'NSD1',
#        'RGS7', 'ARID4A', 'ADNP', 'B2M', 'CTNNB1', 'DOC2A', 'LDHB',
#        'GRIN1', 'CD59', 'PTPN11', 'NRCAM', 'HNRNPK', 'NUMA1', 'NUP62',
#        'PPOX', 'CYB5R3', 'ATP2B2', 'ASS1', 'TBL1XR1', 'BCLAF1',
#        'HSP90AB1', 'PLTP', 'TAP1', 'ATG7', 'TCF4', 'HNRNPA2B1', 'SND1',
#        'AK2', 'HTT', 'ITSN2', 'PTPRD', 'EFEMP1', 'TRRAP', 'DNM2', 'FNBP1',
#        'MLF1', 'SLC25A46', 'PPIA', 'GABBR1', 'STK39', 'SIRPA', 'NF1',
#        'NCOR2', 'MYO5A', 'PICALM', 'RXRA', 'LSS', 'GPI', 'GABRA2',
#        'GABRG2', 'ARHGEF12', 'ATN1', 'FDPS', 'NACA', 'RAB18', 'IGF2R',
#        'CHD4', 'PEX2', 'DCTD', 'OCRL', 'SFPQ', 'FKBP5', 'GFPT1', 'NFE2L1',
#        'STMN1', 'SRSF2', 'SPTAN1', 'ATL1', 'GSTK1', 'STAT4', 'NFIX',
#        'PRKAR1A', 'CTNND1', 'ZBTB18', 'VCP', 'XRCC6', 'HLA-DRB1',
#        'DYNC1H1', 'CACNA1A', 'SRGAP3', 'SQSTM1', 'RPS24', 'SOX10',
#        'NCKAP1', 'STAT1', 'OPA1', 'SREBF2', 'ATP1A2', 'CDC42BPB', 'LMNA',
#        'TOP1', 'LTN1', 'MOCS2', 'KIF21A', 'MTOR', 'MYBPC1', 'TGM2',
#        'L1CAM', 'CNTNAP2', 'SMC3', 'DCTN1', 'SMOC1', 'FH', 'ACTN2',
#        'EGLN1', 'AGT', 'GALNT2', 'PARP1', 'SNRPE', 'PCMT1', 'TAB2',
#        'CITED2', 'ATP1B1', 'MGST3', 'NDUFS2', 'USF1', 'PEX19', 'LAMTOR2',
#        'ADAR', 'TSPYL1', 'UROS', 'OAT', 'HTRA1', 'SEC63', 'VPS45',
#        'PHGDH', 'SLC16A1', 'GSTO1', 'EMD', 'NAA10', 'EXTL2', 'BTRC',
#        'LMO4', 'FHL1', 'SLC9A6', 'DHCR24', 'LGI1', 'SCP2', 'EPS15',
#        'CMPK1', 'PTEN', 'SURF1', 'RALGDS', 'SLC2A1', 'PPT1', 'MRPS16',
#        'CCND3', 'AGO1', 'STXBP1', 'COX7B', 'ATRX', 'GIGYF2', 'OGT', 'GSN',
#        'RPL11', 'C1QC', 'BRD2', 'PSMB8', 'IQSEC2', 'ACBD5', 'FGF14',
#        'DDX39B', 'HLA-C', 'FLOT1', 'HLA-A', 'CST3', 'KCNC3', 'SLITRK1',
#        'SPRY2', 'TRIM27', 'EDNRB', 'PCDH9', 'NDUFAF5', 'GBA2', 'APRT',
#        'ATP6AP2', 'ITM2B', 'UQCRQ', 'SAT1', 'E2F4', 'PRNP', 'FRY',
#        'SERPINB6', 'FRMPD4', 'PSIP1', 'IDH3B', 'IL6ST', 'FKBP1A', 'TUSC3',
#        'SACS', 'DEAF1', 'DNAJC19', 'ZMYM2', 'AQP4', 'KCNQ3', 'STK38L',
#        'ATXN2', 'PTPRN2', 'KMT2A', 'TFPT', 'XRCC5', 'PDCD10', 'SERPINA3',
#        'SLC35G2', 'PC', 'RPL24', 'CHD2', 'MATR3', 'ALDOA', 'ZNF365',
#        'GATM', 'PAFAH1B1', 'CHMP1A', 'MEG3', 'GSTP1', 'IFITM3', 'DDX3X',
#        'HSF1', 'EFTUD2', 'TF', 'FAM131B', 'NT5C3A', 'MIAT', 'ACTB',
#        'HSD17B4', 'GDI1', 'SGCE', 'PTPRJ', 'SRGAP2', 'MMAB', 'PLP1',
#        'CNBP', 'SYN2', 'EIF2B5', 'TREX1', 'LSM14A', 'TRAPPC9', 'ATP1A3',
#        'PET100', 'GRIA3', 'PEG10', 'AGK', 'NDUFA6', 'GCLC', 'SRP72',
#        'SMAD5', 'MALAT1', 'DDX6', 'KIRREL3', 'RDX', 'C1R', 'MTHFD1',
#        'IGF1R', 'CYFIP1', 'TBC1D24', 'ACTG1', 'RPL26', 'NCOA4', 'PRKCSH',
#        'APOC1', 'TAF15', 'ACACA'], dtype=object)

# %%
## Display number of isoforms for key genes I am interested in
medically_relevant_counts_multiple_iso.loc[medically_relevant_counts_multiple_iso["gene_name"].isin(["MAPT", "APP", "SNCA", "PARK7", "PINK1"])]["gene_name"].value_counts()
# Out:
# SNCA     6
# APP      4
# MAPT     3
# PINK1    2
# PARK7    2
# Name: gene_name, dtype: int64

# %%
## Display number of isoforms for key genes I am interested in
medically_relevant_counts_multiple_iso.loc[medically_relevant_counts_multiple_iso["gene_id"].isin(ad_names["gene_id"])]["gene_name"].value_counts()
# Out:
# CTSB     5
# BIN1     4
# CLU      4
# APP      4
# COX7C    3
# WNT3     2
# NCK2     2
# SORT1    2
# WDR12    2
# ANK3     2
# JAZF1    2
# TNIP1    2
# DOC2A    2
# Name: gene_name, dtype: int64

# %%
## Display number of isoforms for key genes for all
medically_relevant_counts_multiple_iso["gene_name"].value_counts()
# Out:
# HNRNPA2B1     14
# GNAS          12
# CRYAB         10
# DTNA          10
# RPS24          8
# SNAP25         8
# NTRK2          8
# SNRPN          7
# HSPB1          7
# ACTB           7
# BSCL2          7
# CSDE1          6
# MAPK10         6
# FDPS           6
# ABI1           6
# SNCA           6
# CHN1           6
# SPP1           6
# DST            6
# ANK2           6
# PKM            6
# SLC1A3         6
# KCNAB2         6
# GRHPR          5
# CALM3          5
# UQCRQ          5
# HLA-A          5
# HSPA9          5
# COX4I1         5
# NACA           5
# KIF5A          5
# FIP1L1         5
# MEG3           5
# MATR3          5
# DGUOK          5
# CTSB           5
# KIF1B          5
# DCTN1          5
# CALM2          5
# PSIP1          5
# DDX5           5
# IL6ST          5
# CCND3          5
# ACADVL         5
# LDHB           4
# GRIN1          4
# MFN2           4
# APP            4
# CD59           4
# NRCAM          4
# SYNE1          4
# HNRNPK         4
# CTNNB1         4
# KLC1           4
# RPS15          4
# PC             4
# ALDOA          4
# B2M            4
# BCAN           4
# SERPINB6       4
# HNRNPU         4
# RHOA           4
# PCMT1          4
# FBXO7          4
# DNM1L          4
# FTH1           4
# QKI            4
# SOX10          4
# DYNC1H1        4
# STXBP1         4
# VCP            4
# ATL1           4
# SPTAN1         4
# RANBP2         4
# ILK            4
# SCN2A          4
# SFPQ           4
# UQCRB          4
# PREPL          4
# ST6GALNAC6     4
# TPI1           4
# DYSF           4
# TUBA1A         4
# PPIA           4
# NPM1           4
# COX6C          4
# PRNP           4
# BIN1           4
# CAMTA1         4
# BANF1          4
# NDRG1          4
# ACO2           4
# PSEN1          4
# MT-TQ          4
# GNPTG          4
# SPTBN1         4
# CNBP           4
# PPP3CA         4
# NEFM           4
# CTNNA2         4
# RPL26          4
# BSG            4
# CLU            4
# ABHD12         4
# PMP22          4
# GLUL           4
# HSD17B4        4
# RPL35A         4
# HSF1           4
# DNM1           4
# SLC25A3        4
# SLC44A2        4
# CTSA           4
# PPP2R2B        4
# PABPC1         4
# DDX3X          4
# NDUFB1         4
# ANKS1B         4
# FAM131B        4
# HDLBP          4
# RPL38          4
# FKBP8          4
# EIF4A2         4
# CPLX2          4
# QDPR           3
# HLA-DRB1       3
# PIP5K1C        3
# SNAPC5         3
# PRKAR1A        3
# NFIX           3
# PPM1B          3
# HIF1A          3
# ROGDI          3
# KTN1           3
# SET            3
# SLC14A1        3
# NFE2L1         3
# UCHL1          3
# FKBP5          3
# HBA1           3
# HBB            3
# UNC80          3
# CNKSR2         3
# DKK3           3
# SDHA           3
# MGLL           3
# RAB7A          3
# EWSR1          3
# ATP1B1         3
# NRXN1          3
# ADAM22         3
# HNRNPH3        3
# PARP1          3
# CADM1          3
# ATP2C1         3
# ACTN2          3
# SERPING1       3
# TPM1           3
# MYBPC1         3
# CLTC           3
# ATP13A2        3
# TPM3           3
# ACP1           3
# SLC4A10        3
# DDX41          3
# CHD4           3
# BRWD1          3
# NONO           3
# UBA1           3
# MSRA           3
# FGFR2          3
# COQ4           3
# STIM1          3
# PRRT2          3
# ATG7           3
# UNC119         3
# HSP90AB1       3
# SMARCA2        3
# TBL1XR1        3
# CTNNA1         3
# ATP2B2         3
# CYB5R3         3
# RPS14          3
# ADD1           3
# PTPN11         3
# AFDN           3
# NFU1           3
# KRT17          3
# MAP6           3
# MAP2K1         3
# LGI4           3
# SNCB           3
# USP7           3
# SYNPO          3
# ZHX3           3
# RNASEH2C       3
# BCL2L1         3
# PFKM           3
# PDE4DIP        3
# RAB18          3
# HERPUD1        3
# HMGCR          3
# OBSL1          3
# ABR            3
# NTRK3          3
# ETFDH          3
# TNNT1          3
# GPI            3
# MEF2A          3
# ATP1A1         3
# WNK1           3
# SERPINI1       3
# STK39          3
# GABBR1         3
# RPL5           3
# CDC42          3
# NDUFAF2        3
# ZMYM3          3
# MEF2C          3
# B4GALNT1       3
# CFL2           3
# SCN3B          3
# DPM3           3
# ATP2B4         3
# PTPRD          3
# AK2            3
# RIMS1          3
# SULT4A1        3
# HEXB           3
# PRDM2          3
# ITM2B          3
# ATP6AP2        3
# PCDH9          3
# TREX1          3
# ATP1A3         3
# CST3           3
# FXYD6          3
# LRPPRC         3
# SHTN1          3
# HLA-C          3
# DDX39B         3
# MIF            3
# TECR           3
# IMMT           3
# B9D1           3
# BRD2           3
# RPL11          3
# TTC19          3
# GSN            3
# LAMP2          3
# DNAJB6         3
# MAP2           3
# COX7B          3
# DLG3           3
# MAPT           3
# GNAO1          3
# SAT1           3
# FUS            3
# TYROBP         3
# PNKD           3
# EEF1B2         3
# SGK1           3
# C12orf57       3
# PAFAH1B1       3
# WFS1           3
# RANGRF         3
# PTPRN2         3
# MBOAT7         3
# C3             3
# UROD           3
# AQP4           3
# COX7C          3
# PON2           3
# GFAP           3
# DNAJC19        3
# EMC4           3
# MIAT           3
# GDI1           3
# SGCE           3
# FKBP1A         3
# IDH3B          3
# NDUFA2         3
# FRMPD4         3
# ARHGEF9        3
# ARHGEF7        3
# HUWE1          3
# MRPS34         3
# GGCX           3
# CUL3           3
# APOC1          3
# ARID4B         3
# SCP2           3
# PRKCSH         3
# CD74           3
# BRD4           3
# CAST           3
# GSTO1          3
# ERCC1          3
# MFF            3
# LGI1           3
# DNAJC6         3
# YWHAE          3
# FHL1           3
# GOPC           3
# NDUFV3         3
# DCN            3
# GABRA1         3
# CD81           3
# UROS           3
# ROM1           3
# RALGDS         3
# EXTL2          3
# PPP6C          3
# CYFIP1         3
# KEAP1          3
# BTRC           3
# THRA           3
# MAP2K4         3
# GAD1           2
# TBK1           2
# OPCML          2
# NCOA4          2
# PTPRJ          2
# SMAD4          2
# EXT2           2
# DPP6           2
# TRIO           2
# PCLO           2
# TBC1D24        2
# DICER1         2
# ACTG1          2
# CSGALNACT1     2
# SMAD5          2
# KCNQ2          2
# BCAP31         2
# ZNF365         2
# DDIT3          2
# GATM           2
# CHMP1A         2
# UBE2A          2
# MYLK           2
# NNAT           2
# RNF6           2
# TAF15          2
# PRICKLE1       2
# FBXW4          2
# GSTP1          2
# BGN            2
# IFITM3         2
# GLRX5          2
# EFTUD2         2
# RPL10          2
# RPS10          2
# POMGNT2        2
# DROSHA         2
# LARP7          2
# NF2            2
# TF             2
# NT5C3A         2
# SRGAP2         2
# NR3C2          2
# EIF4G1         2
# MMAB           2
# CSMD1          2
# PEG10          2
# AGK            2
# ELAC2          2
# EBAG9          2
# NIPA1          2
# NDUFA6         2
# KIRREL3        2
# GCLC           2
# RAD51C         2
# SOD2           2
# GABRA5         2
# NPAS2          2
# EZR            2
# AGTPBP1        2
# DDX6           2
# BCL11A         2
# GRB10          2
# LRRFIP2        2
# SRP72          2
# MALAT1         2
# DNAJB2         2
# ZBTB16         2
# ZFP36L1        2
# LIMK1          2
# SHANK2         2
# PARK7          2
# DYRK1A         2
# ACSL4          2
# FUT8           2
# IGF1R          2
# SMPD1          2
# PLP1           2
# FHIT           2
# MPC1           2
# SYN2           2
# MTHFD1         2
# EIF2B5         2
# LSM14A         2
# IDS            2
# TRAPPC9        2
# SF3B1          2
# UBE3B          2
# USP1           2
# NUDT1          2
# SRSF3          2
# PET100         2
# GRIA3          2
# C1R            2
# RDX            2
# USP9Y          2
# DTNBP1         2
# WASF3          2
# TSPYL1         2
# KCNQ3          2
# CHD2           2
# CACNA1A        2
# CMPK1          2
# CDC42BPB       2
# ATP1A2         2
# SREBF2         2
# OPA1           2
# STAT1          2
# PTEN           2
# NCKAP1         2
# SURF1          2
# SLC2A1         2
# SQSTM1         2
# SRGAP3         2
# PPT1           2
# MRPS16         2
# AGO1           2
# TOP1           2
# XRCC6          2
# ZBTB18         2
# ATRX           2
# CTNND1         2
# GIGYF2         2
# STAT4          2
# OGT            2
# GSTK1          2
# SRSF2          2
# C1QC           2
# STMN1          2
# PSMB8          2
# GFPT1          2
# IQSEC2         2
# EPS15          2
# DHCR24         2
# RPL24          2
# GALNT2         2
# OAT            2
# LAMTOR2        2
# HTRA1          2
# PEX19          2
# SEC63          2
# USF1           2
# NDUFS2         2
# MGST3          2
# VPS45          2
# CITED2         2
# TAB2           2
# PHGDH          2
# SLC16A1        2
# SNRPE          2
# EMD            2
# LTN1           2
# NAA10          2
# AGT            2
# EGLN1          2
# FH             2
# SMOC1          2
# SMC3           2
# CNTNAP2        2
# L1CAM          2
# TGM2           2
# LMO4           2
# MTOR           2
# SLC9A6         2
# KIF21A         2
# MOCS2          2
# ACBD5          2
# OCRL           2
# DCTD           2
# ATXN2          2
# TUSC3          2
# SACS           2
# DEAF1          2
# TCF4           2
# TAP1           2
# PLTP           2
# BCLAF1         2
# ZMYM2          2
# ASS1           2
# ADAR           2
# PPOX           2
# NUP62          2
# NUMA1          2
# STK38L         2
# KMT2A          2
# PEX2           2
# TFPT           2
# XRCC5          2
# DOC2A          2
# PDCD10         2
# SERPINA3       2
# SLC35G2        2
# ADNP           2
# ARID4A         2
# RGS7           2
# NSD1           2
# CNTN1          2
# CLCN3          2
# RPL36          2
# PSAT1          2
# SND1           2
# HTT            2
# ITSN2          2
# FRY            2
# FGF14          2
# IGF2R          2
# FLOT1          2
# ATN1           2
# ARHGEF12       2
# GABRG2         2
# GABRA2         2
# KCNC3          2
# SLITRK1        2
# SPRY2          2
# TRIM27         2
# LSS            2
# RXRA           2
# PICALM         2
# MYO5A          2
# EDNRB          2
# NCOR2          2
# NF1            2
# NDUFAF5        2
# GBA2           2
# SIRPA          2
# APRT           2
# SLC25A46       2
# E2F4           2
# MLF1           2
# FNBP1          2
# DNM2           2
# TRRAP          2
# EFEMP1         2
# LMNA           2
# NAGPA          2
# CHD3           2
# CLCN7          2
# NLRP1          2
# PITPNM3        2
# CSNK2A2        2
# SEC23B         2
# SCN1B          2
# ITCH           2
# PAFAH1B3       2
# MAP2K2         2
# OPTN           2
# SMARCB1        2
# EP300          2
# PRKCG          2
# ATP2B3         2
# FOXRED1        2
# SIAE           2
# KCNT1          2
# TP53BP1        2
# AKT3           2
# EHBP1          2
# KANSL1         2
# TRIM37         2
# SV2B           2
# MTUS1          2
# GPNMB          2
# CCM2           2
# KAT7           2
# LRRC8A         2
# TUBB2B         2
# FAM8A1         2
# ADCY3          2
# WDR12          2
# ITGAV          2
# TMPO           2
# CCND2          2
# MAN2A1         2
# MSMO1          2
# PALLD          2
# LPIN2          2
# SLC7A5         2
# SREBF1         2
# SPG11          2
# PHF3           2
# MCOLN1         2
# ATF2           2
# RAB3GAP1       2
# ORC4           2
# TCF12          2
# ETFA           2
# MFGE8          2
# ABAT           2
# FTO            2
# SPG7           2
# NCOR1          2
# G6PC3          2
# GNAL           2
# DYM            2
# SH3GL1         2
# SOD1           2
# RPS27A         2
# UBR3           2
# NICN1          2
# RASA1          2
# MEGF10         2
# ARHGAP26       2
# NHP2           2
# DIABLO         2
# SUOX           2
# PEX5           2
# FBXW11         2
# ECE1           2
# GLRB           2
# RAP1GDS1       2
# SMARCE1        2
# NNT            2
# MTRR           2
# OLFM2          2
# MAP3K13        2
# SHOC2          2
# GNAI2          2
# NRXN2          2
# MGST2          2
# LARS2          2
# NSMF           2
# EIF4H          2
# LZTS1          2
# CPEB3          2
# DAXX           2
# RCBTB1         2
# KMT2E          2
# FOLH1          2
# VIM            2
# SYNGR1         2
# HSP90AA1       2
# SUPT16H        2
# APEX1          2
# PABPN1         2
# ARHGAP5        2
# NFKBIA         2
# EEF1A2         2
# WDR13          2
# FMR1           2
# PQBP1          2
# USB1           2
# FDFT1          2
# GDAP1          2
# EIF3E          2
# PNPLA6         2
# FCGRT          2
# CLIP2          2
# AK1            2
# XBP1           2
# COMT           2
# GOLGA3         2
# MT-TS1         2
# ZNF429         2
# PSENEN         2
# KHK            2
# CRBN           2
# NELFA          2
# POLB           2
# ALDH1A1        2
# MAOB           2
# SMS            2
# SPG21          2
# RB1CC1         2
# RNASET2        2
# KIF22          2
# REEP1          2
# ASNS           2
# ALDH3A2        2
# ACTN1          2
# EPB41L1        2
# SETX           2
# SLC25A39       2
# ACP2           2
# GIT1           2
# ELK1           2
# PIN1           2
# TST            2
# CALU           2
# DMXL2          2
# MEGF8          2
# HBA2           2
# PCCB           2
# RAF1           2
# LDLR           2
# ACTN4          2
# NDUFA10        2
# ZNF331         2
# ATP6V1E1       2
# EFR3A          2
# SERPINF1       2
# CHL1           2
# SORT1          2
# LPIN1          2
# RALY           2
# MAX            2
# BBS2           2
# RPL22          2
# WNT3           2
# GOSR2          2
# KAT2A          2
# LDHA           2
# PPFIBP1        2
# BCL6           2
# NCK2           2
# MPV17          2
# HMGCL          2
# ATXN1          2
# CTSD           2
# B4GALT6        2
# MXI1           2
# RNF170         2
# TARDBP         2
# MAPK8IP1       2
# PEPD           2
# CDKN1A         2
# NLGN4X         2
# RSPO2          2
# NDUFB9         2
# TUBA8          2
# MED25          2
# PRCP           2
# CADPS2         2
# NDUFS8         2
# OSBPL2         2
# FAM20C         2
# FUZ            2
# RCAN1          2
# BTBD9          2
# ASAH1          2
# SPECC1L        2
# PPP2R2C        2
# CD55           2
# TNIP1          2
# ST8SIA5        2
# GPHN           2
# TUBB3          2
# CD200          2
# ABCD3          2
# STX16          2
# LRP4           2
# TMEM70         2
# CTSF           2
# ATP2A2         2
# SEZ6L2         2
# DAG1           2
# NDUFA11        2
# ETFB           2
# EEF1A1         2
# B4GALT2        2
# SPTBN2         2
# HCFC1          2
# NSD2           2
# GPD2           2
# MRPL48         2
# MRPS22         2
# TNS3           2
# RABL6          2
# MLC1           2
# COMMD1         2
# MEN1           2
# TFE3           2
# KCNA2          2
# SEC23A         2
# CALR           2
# NDUFV1         2
# PLEC           2
# TCOF1          2
# SNRNP200       2
# FN1            2
# SCN4B          2
# CEP57          2
# PRKRA          2
# FGFR1          2
# CRELD1         2
# PEG3           2
# NDUFAF3        2
# JMJD1C         2
# NDUFA12        2
# COL4A5         2
# COA5           2
# GALNT9         2
# NOP56          2
# PEX26          2
# SMC1A          2
# CD151          2
# CRTC1          2
# TALDO1         2
# SLC9A9         2
# LLGL1          2
# NSD3           2
# CAPN3          2
# CRAT           2
# BBS1           2
# ABL1           2
# A2M            2
# MCFD2          2
# PRKCB          2
# ARID1B         2
# B4GALT3        2
# SLC25A22       2
# KIF1A          2
# NQO1           2
# PIK3R1         2
# FMN1           2
# PINK1          2
# AFF1           2
# KIAA0232       2
# CIZ1           2
# ETNPPL         2
# ADK            2
# TSPAN7         2
# KAT6B          2
# AIFM1          2
# SLC6A1         2
# ASTN2          2
# SLC12A6        2
# IFNGR2         2
# ALDH4A1        2
# CBFB           2
# ETHE1          2
# SYNGAP1        2
# NCKIPSD        2
# AZIN2          2
# BOLA3          2
# IGFBP7         2
# TGFBR2         2
# SYN1           2
# GYG1           2
# SLC24A2        2
# TMEM237        2
# ERCC3          2
# ATP8A2         2
# GLUD1          2
# DLAT           2
# PTS            2
# USP15          2
# THRB           2
# ANK3           2
# NRXN3          2
# NBAS           2
# CACNB2         2
# LY96           2
# FLT1           2
# NADK2          2
# GPD1L          2
# TIA1           2
# LIPA           2
# SCN3A          2
# JAZF1          2
# MSI2           2
# PPP1CB         2
# NDUFS4         2
# SLCO1A2        2
# RAD21          2
# SCN1A          2
# BTD            2
# AUH            2
# ZEB2           2
# CHST11         2
# CHCHD7         2
# REPS2          2
# HINT1          2
# TMEM126A       2
# PRPF8          2
# GAP43          2
# GRM5           2
# CERS6          2
# BCR            2
# ST3GAL5        2
# FASN           2
# GFRA2          2
# GPS1           2
# USP8           2
# MECP2          2
# HCN1           2
# RFXANK         2
# STAT6          2
# PDP1           2
# PHKB           2
# GABRB3         2
# PCBD1          2
# TPP1           2
# COG1           2
# ZNF592         2
# NAB2           2
# CRK            2
# POLR1D         2
# VKORC1         2
# TPM4           2
# KMT2D          2
# SPINT2         2
# SDHAF2         2
# KCND3          2
# KCNAB1         2
# DLG4           2
# ACACA          2
# Name: gene_name, dtype: int64

# %%
## How many highly expressed isoforms are there for each gene?
df_numbers = medically_relevant_counts_multiple_iso["gene_name"].value_counts()

# %%
medically_relevant_counts_multiple_iso['Number of Isoforms'] = medically_relevant_counts_multiple_iso['gene_id'].copy().map(medically_relevant_counts_multiple_iso['gene_id'].value_counts())

# %%
medically_relevant_counts_multiple_iso.drop_duplicates(inplace=True, subset="gene_id")

# %%
medically_relevant_counts_multiple_iso.head()
# Out:
#        transcript_id          gene_id  cshl_356_uky_CPM  cshl_1271_uky_CPM  \
# 6              tx.49  ENSG00000132692             39.91              40.27
# 38   ENST00000378623  ENSG00000134569             10.78              16.26
# 43            tx.127  ENSG00000149489              7.40              11.41
# 79            tx.221  ENSG00000067225            235.90             792.64
# 113  ENST00000353533  ENSG00000065559             11.16              14.45
#
#      cshl_1291_uky_CPM  cshl_1304_uky_CPM  total_CPM is_novel_transcript  \
# 6                25.59              38.03      36.37                True
# 38               28.33              14.67      17.19               False
# 43                8.66               8.27       9.01                True
# 79               65.24             303.45     369.91                True
# 113              16.25              13.48      13.83               False
#
#     is_novel_gene gene_name  Number of Isoforms
# 6           False      BCAN                   4
# 38          False      LRP4                   2
# 43          False      ROM1                   3
# 79          False       PKM                   6
# 113         False    MAP2K4                   3

# %%
medically_relevant_counts_multiple_iso = medically_relevant_counts_multiple_iso.loc[medically_relevant_counts_multiple_iso["Number of Isoforms"] <= 6]

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 12,8
rcParams.update({'font.size': 28})
rcParams['axes.linewidth'] = 6

# %%
sns.countplot(x="Number of Isoforms", data=medically_relevant_counts_multiple_iso, palette="nipy_spectral")
sns.despine()
plt.ylabel("Number of Genes")
plt.savefig('../../figures/bioinfo_presentation/multiple_isoforms_in-person.png', dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
#chm13_novel_genes.drop(columns=["is_novel_transcript", "is_novel_gene"], inplace=True)

grch38_novel_genes["Label"] = "New Genes"

# %%
all_novel_genes = grch38_novel_genes.copy()

# %%
all_novel_genes = all_novel_genes[(all_novel_genes["total_CPM"]>1)]

# %%
all_novel_genes.shape
# Out:
# (79, 10)

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 8,12
rcParams.update({'font.size': 28})
rcParams['axes.linewidth'] = 6

# %%
fig, ax1 = plt.subplots()
ax1.yaxis.set_ticks_position("right")
ax1.yaxis.tick_right()
ax1.yaxis.set_label_position("right")

sns.countplot(x="Label", data=all_novel_genes, palette="nipy_spectral", ax=ax1)

plt.ylabel("Number of Genes", rotation=270, labelpad=40)
plt.xlabel("", labelpad=4)
sns.despine(right=False, left=True, top=True, bottom=False)

plt.savefig('../../figures/bioinfo_presentation/novel_genes_in-person.png', dpi=300, transparent=True, bbox_inches="tight")
plt.show()
