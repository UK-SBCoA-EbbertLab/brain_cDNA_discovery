# %%
## Import Libraries
import pandas as pd
import numpy as np
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import seaborn as sns

## Display all rows of pandas dataframes
pd.set_option('display.max_rows', None)

# %%
'''
function name: calculate_cpm

purpose: Calculate CPM for the each sample given

input: Counts dataset

output: Counts dataset with CPM columns as well
'''

def calculate_cpm(df, is_gene=False):

    ## Set count columns if dataframe is gene counts
    if is_gene:
        count_columns = df.columns[1:].tolist()
    
    ## Set count columns if dataframe is transcript counts
    else:
        count_columns = df.columns[2:].tolist()

    ## Loop through counts columns to calculate CPM and add to the dataframe
    for col in count_columns:
        
        df[col] = round(df[col], 2)
        cpm_name = col.replace("_counts", "_CPM")
        df[cpm_name] = round(((df[col]/(df[col].sum())) * 1000000), 2)
    
    return df

# %%
'''
function name: fix_column_names

purpose: Fixing the column names, making them smaller, informative, and consistent

input: The raw counts dataframe for either genes or transcripts 

output: Same dataframe with improved column names
'''

def fix_column_names(df, is_gene=False):
    
    ## Check if this is a gene counts object
    if is_gene:
        
        ## Get count column names and create list of new column names
        count_columns = df.columns.tolist()
        list_new_names = ["gene_id"]
        
        ## gene_id comes in as index for gene counts data, make it into the first column instead
        df["gene_id"] = df.index
        cols = list(df.columns)
        cols = [cols[-1]] + cols[:-1]
        df = df[cols]
        df.reset_index(inplace=True, drop=True)
    
    ## If it is a transcript dataset
    else:
        ## Set count columns and create list of new names
        count_columns = df.columns[2:].tolist()
        list_new_names = [ "transcript_id", "gene_id"]
    
    ## Fix names one by one and add to list of new names
    for col in count_columns:
        col = col.split("_mapped")[0] + "_counts"
        list_new_names.append(col)
    
    ## Rename columns
    df.columns = list_new_names
    
    return df

# %%
'''
name: relative_transcript_abundance

purpose: calculate relative transcript abundance

input: a dataframe with a ref_gene_id column identifying the transcript gene of origin and a cov columns with 
the coverage for the transcripts.

output: the same dataframe with a relative abundance column added
'''



def relative_transcript_abundance(df):
    
    df_sums = df[["gene_id", "total_CPM"]].groupby("gene_id").sum()
    
    df_sums["total_CPM_gene"] = df_sums["total_CPM"]

    df_sums.drop(columns="total_CPM", inplace=True)
    
    merged_df = pd.merge(df, df_sums, how='inner', on="gene_id")
    
    merged_df["relative_abundance_percent"] = ((merged_df["total_CPM"]/merged_df["total_CPM_gene"]) * 100)
    
    merged_df.drop(columns="total_CPM", inplace=True)
    
    return merged_df

# %%
'''
function name: parse_df_columns

purpose: parsing the last aggregate column of the gtf/gff3 into useful columns and cleaning non-relevant columns

input: dataframe containining "raw" gtf/gff

output: dataframe containing gtf with useful columns ["gene_id", "transcript_id", etc...]
'''

def parse_df_columns(df, is_ref=True):

    if is_ref:

        ## Get gene ids
        df["gene_id"] = df["other"].str.split("source_gene=", expand=True)[1].str.split(';', expand=True)[0]

        ## Get transcript ids
        df["transcript_id"] = df["other"].str.split("source_transcript=", expand=True)[1].str.split(';', expand=True)[0]

        ## Get CHM gene_ids
        df["CHM_gene_id"] = df["other"].str.split("gene_id=", expand=True)[1].str.split(';', expand=True)[0]

        ## Get transcript ids
        df["CHM_transcript_id"] = df["other"].str.split("transcript_id=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get transcript names
        df["transcript_name"] = df["other"].str.split("source_transcript_name=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get gene names
        df["gene_name"] = df["other"].str.split("source_gene_common_name=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get start codon
        df["start_codon"] = df["other"].str.split("adj_start=", expand=True)[1].str.split(";", expand=True)[0]
        
        ## Get stop codon
        df["stop_codon"] = df["other"].str.split("adj_stop=", expand=True)[1].str.split(";", expand=True)[0]        

        ## Only keep relevant
        df = df[["chr", "start", "end", "strand", "type", "gene_id", "transcript_id", "CHM_gene_id",
                 "CHM_transcript_id", "transcript_name", "gene_name", "start_codon", "stop_codon"]].copy()

        ## Drop duplicates
        df.drop_duplicates(inplace=True)
        

    else:

        ## Get CHM gene ids
        df["gene_id"] = df["other"].str.split('";', expand=True)[0].str.extract("([^ \"]*$)", expand=True)

        ## Get CHM transcript ids
        df["transcript_id"] = df["other"].str.split('transcript_id "', expand=True)[1].str.split('"', expand=True)[0]

        ## Get exon number
        df["exon_number"] = df["other"].str.split('exon_number "', expand=True)[1].str.split('"', expand=True)[0]

        ## Label novel transcripts
        df.loc[df["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = True
        df.loc[~df["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = False

        ## Label novel genes
        df.loc[df["gene_id"].str.startswith("gene."), "is_novel_gene"] = True
        df.loc[~df["gene_id"].str.startswith("gene."), "is_novel_gene"] = False

        ## Drop "other" column
        df.drop(columns=["other", "dot_1", "dot_2"], inplace=True)

    for col in df.columns:
        df.loc[df[col].isnull(), col] = np.NaN
        

    return df

# %%
'''
function name: merge_annotations

purpose: Merge useful/relevant information from both annotations while removing repeated and irrelevant information

input: Two different GTF annotations

output: One GTF annotation containing all the relevant information
'''

def merge_annotations(ref_gtf, bambu_gtf):
    
    ## Merge the two annotations
    names_ref_gtf = ref_gtf[["transcript_id", "gene_id", "gene_name", "transcript_name"]].copy()
    merged_gtf = pd.merge(bambu_gtf, names_ref_gtf, on=['gene_id', 'transcript_id'], how='left')
    merged_gtf.drop_duplicates(inplace=True)

    ## Label novel transcripts
    merged_gtf.loc[merged_gtf["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = True
    merged_gtf.loc[~merged_gtf["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = False

    ## Label novel genes
    merged_gtf.loc[merged_gtf["gene_id"].str.startswith("gene."), "is_novel_gene"] = True
    merged_gtf.loc[~merged_gtf["gene_id"].str.startswith("gene."), "is_novel_gene"] = False

    ## Create temporary variable only containing novel transcripts
    temp = merged_gtf.loc[merged_gtf["is_novel_transcript"] == True]

    ## Annotate novel transcripts
    merged_tmp = pd.merge(temp, ref_gtf[["gene_id", "gene_name"]], on=['gene_id'], how='left')
    merged_tmp.drop_duplicates(inplace=True)
    merged_tmp["gene_name"] = merged_tmp["gene_name_y"]
    merged_tmp.drop(columns=["source", "gene_name_y", "gene_name_x"], inplace=True)

    ## Return novel transcripts to original annotation
    merged_final = pd.merge(merged_gtf, merged_tmp, on=['chr', 'type', 'start', 'end', 'strand', 'transcript_id',
                    'transcript_name', 'gene_id', 'is_novel_transcript', 'is_novel_gene', 'exon_number'], how="left")

    ## Get gene names for novel transcripts of known genes
    merged_final.gene_name_x.fillna(merged_final.gene_name_y, inplace=True)
    merged_final["gene_name"] = merged_final["gene_name_x"]
    merged_final.drop(columns =["gene_name_x", "gene_name_y"], inplace=True)
    
    ## Get start and stop codons for known transcripts and exons of protein coding genes
    ref_gtf = ref_gtf[["chr", "type", "start", "end", "strand", "transcript_id", "gene_id", "start_codon", "stop_codon"]]
    merged_final = pd.merge(merged_final, ref_gtf, on=["chr", "type", "start", "end", "strand", "transcript_id", "gene_id"], how="left")
    
    
    merged_final = merged_final[["chr", "type", "start", "end", "strand", "transcript_id", "gene_id", "gene_name", 
                    "exon_number", "transcript_name", "start_codon", "stop_codon", "is_novel_gene", "is_novel_transcript"]]


    
    return merged_final

# %%
'''
name: make_gene_and_transcript_converter

input: The CHM13 CAT/Liftoff gff annotation version 2.0

output: A dataframe with ["gene_id", "transcript_id", "gene_name", "transcript_name"] formatted in the same way as the 
bambu reference, so that we can properly assign gene and transcript names.

purpose: Creating a list that allows us to assign transcript and gene names to the bambu annotation based on the transcript
id and gene ID
'''


def make_gene_and_transcript_converter(gff):
    
    ## Change name of duplicate Ensembl IDs to CHM IDs
    gff.loc[gff["transcript_id"] == "N/A", "transcript_id"] = gff["CHM_transcript_id"]
    gff_transcripts = gff.loc[gff["type"] == "transcript"].copy()
    gff_transcripts = gff_transcripts[["transcript_id", "CHM_transcript_id"]].drop_duplicates()
    gff_transcripts = gff_transcripts[gff_transcripts['transcript_id'].duplicated() == True]
    dup_trans = gff_transcripts["transcript_id"].dropna().values.tolist()
    gff.loc[gff["transcript_id"].isin(dup_trans), "transcript_id"] = gff["transcript_id"] + "(" + gff["CHM_transcript_id"] + ")"

    ## Change name of duplicate gene ids to CHM ids
    gff.loc[gff["gene_id"] == "None", "gene_id"] = gff["CHM_gene_id"]
    gff_genes = gff.loc[gff["type"] == "transcript"].copy()
    gff_genes = gff_genes[["gene_id", "CHM_gene_id"]].drop_duplicates()
    gff_genes = gff_genes[gff_genes['gene_id'].duplicated() == True]
    dup_genes = gff_genes["gene_id"].dropna().values.tolist()
    gff.loc[gff["gene_id"].isin(dup_genes), "gene_id"] = gff["gene_id"] + "(" + gff["CHM_gene_id"] + ")"

    
    ## Fix gene names for MSTRG Genes
    gff_names = gff.loc[gff["type"] == "transcript"].copy()
    gff_names = gff_names[["gene_id", "gene_name"]].copy()
    gff_names.loc[gff_names["gene_name"].str.contains("MSTRG."), "gene_name"] = np.NaN
    gff_names.dropna(inplace=True)
    gff_names.drop_duplicates(inplace=True, subset=["gene_id"])
    gff.drop(columns="gene_name", inplace=True)
    gff = pd.merge(gff, gff_names, on="gene_id", how="left")
    gff = gff[["gene_id", "transcript_id", "gene_name", "transcript_name",
              "start", "end", "type", "start_codon", "stop_codon", "chr", "strand"]].copy()


    return gff

# %%
## Fix column names in counts matrix

chm13_counts = pd.read_csv("../../data/raw/merged_uky_cshl_CHM13_discovery/bambu_discovery/counts_transcript.txt", 
                           delimiter="\t", low_memory=False, header=0)

chm13_counts = fix_column_names(chm13_counts, is_gene=False)

# %%
chm13_counts.loc[chm13_counts["gene_id"].str.contains("ENSG00000108379")]
# Out:
#             transcript_id             gene_id  cshl_1271_uky_counts  \
# 679                tx.680  ENSG00000108379.10           1687.450276
# 4462    ENST00000225512.6  ENSG00000108379.10            570.000000
# 162335  ENST00000573788.5  ENSG00000108379.10             13.549724
#
#         cshl_1304_uky_counts  cshl_1291_uky_counts  cshl_356_uky_counts
# 679               2116.93369               0.00001           1191.43434
# 4462               476.00000             380.00000            333.00000
# 162335               2.06631              87.99999             24.56566

# %%
## Calculate total counts and fix gene id
chm13_counts["total_counts"] = chm13_counts[chm13_counts.columns[2:6].tolist()].sum(axis=1)

# %%
## Calculate CPM and drop count columns
chm13_counts = calculate_cpm(chm13_counts, is_gene=False)

chm13_counts = chm13_counts[chm13_counts.columns.drop(list(chm13_counts.filter(regex='counts')))]

# %%
## Find novel transcripts in both annotations
chm13_counts.loc[chm13_counts["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = True
chm13_counts.loc[~chm13_counts["transcript_id"].str.startswith("tx."), "is_novel_transcript"] = False

## Find novel genes in both annotations
chm13_counts.loc[chm13_counts["gene_id"].str.startswith("gene."), "is_novel_gene"] = True
chm13_counts.loc[~chm13_counts["gene_id"].str.startswith("gene."), "is_novel_gene"] = False

# %%
chm13_counts_with_name.loc[chm13_counts_with_name["gene_name"] == "CLU"]
# Out:
#             transcript_id          gene_id  cshl_356_uky_CPM  \
# 90467  ENST00000316403.15  ENSG00000120885           3014.49
# 90468   ENST00000405140.7  ENSG00000120885            104.09
# 90469   ENST00000518050.1  ENSG00000120885              0.19
# 90470   ENST00000519472.5  ENSG00000120885              0.93
# 90471   ENST00000519742.5  ENSG00000120885              0.08
# 90472   ENST00000520491.5  ENSG00000120885              0.00
# 90473   ENST00000520796.5  ENSG00000120885              0.51
# 90474   ENST00000521770.1  ENSG00000120885              1.47
# 90475   ENST00000522098.1  ENSG00000120885              0.32
# 90476   ENST00000522238.1  ENSG00000120885              2.65
# 90477   ENST00000522299.5  ENSG00000120885              2.12
# 90478   ENST00000522413.5  ENSG00000120885              0.14
# 90479   ENST00000522502.1  ENSG00000120885              0.11
# 90480   ENST00000523396.1  ENSG00000120885              0.09
# 90481   ENST00000523500.5  ENSG00000120885             30.68
# 90482   ENST00000523589.5  ENSG00000120885              1.03
# 90483   ENST00000560566.5  ENSG00000120885              1.07
#
#        cshl_1304_uky_CPM  cshl_1271_uky_CPM  cshl_1291_uky_CPM  total_CPM  \
# 90467            5014.83            7274.46            3730.04    4910.46
# 90468              97.33              87.18             139.53     105.18
# 90469               0.29               3.07              10.53       3.24
# 90470               2.48               2.11               1.24       1.77
# 90471               0.12               0.03               0.00       0.06
# 90472               0.03               0.03               0.04       0.03
# 90473               0.67               0.61               0.44       0.57
# 90474               2.44               3.85               3.76       2.89
# 90475               0.56               1.37               1.12       0.85
# 90476               1.08               0.33               1.51       1.32
# 90477               5.84              13.94               9.70       8.05
# 90478               0.23               0.42               0.71       0.36
# 90479               0.18               0.14               0.10       0.14
# 90480               0.12               0.06               0.04       0.08
# 90481              11.71              14.60              26.80      19.92
# 90482               1.60               1.62               1.06       1.36
# 90483               0.91               0.69               1.21       0.95
#
#       is_novel_transcript is_novel_gene gene_name
# 90467               False         False       CLU
# 90468               False         False       CLU
# 90469               False         False       CLU
# 90470               False         False       CLU
# 90471               False         False       CLU
# 90472               False         False       CLU
# 90473               False         False       CLU
# 90474               False         False       CLU
# 90475               False         False       CLU
# 90476               False         False       CLU
# 90477               False         False       CLU
# 90478               False         False       CLU
# 90479               False         False       CLU
# 90480               False         False       CLU
# 90481               False         False       CLU
# 90482               False         False       CLU
# 90483               False         False       CLU

# %%
## Create dataframes with either only novel genes or only novel transcripts that are not from novel genes
chm13_novel_genes = chm13_counts.loc[chm13_counts["is_novel_gene"]].copy()
chm13_novel_transcripts = chm13_counts.loc[((chm13_counts["is_novel_transcript"]) & (~chm13_counts["is_novel_gene"]))].copy()

# %%
## See how many novel genes
print("We found", chm13_novel_genes.shape[0], "novel genes in CHM13")
# Out:
# We found 170 novel genes in CHM13

# %%
## Filter novel genes and transcripts, total CPM > 1
chm13_novel_genes = chm13_novel_genes[(chm13_novel_genes["total_CPM"]>1)]
chm13_novel_transcripts = chm13_novel_transcripts[(chm13_novel_transcripts["total_CPM"]>1)]

# %%
## Count number of novel genes and novel transcripts in each dataframe
print("We found", chm13_novel_genes.shape[0], "novel genes in CHM13")
print("We found", chm13_novel_transcripts.shape[0], "novel transcripts of known genes in CHM13")
# Out:
# We found 81 novel genes in CHM13
# We found 456 novel transcripts of known genes in CHM13

# %%
## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
chm13_ref = pd.read_csv("../../data/raw/merged_uky_cshl_CHM13_discovery/bambu_discovery/extended_annotations.gtf",
                        header=None, delimiter="\t", low_memory=False, 
                        names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"])


chm13_ref = parse_df_columns(chm13_ref, is_ref=False)

# %%
## "Fix" gene_id
chm13_ref["gene_id"] = chm13_ref["gene_id"].str.split(".", expand=True)[0]

# %%
## Only keep transcripts
chm13_ref = chm13_ref.loc[chm13_ref["type"] == "transcript"]

# %%
## Only keep expressed transcripts
chm13_novel_transcripts_expressed = chm13_ref.loc[chm13_ref["transcript_id"].isin(
                                                    chm13_novel_transcripts["transcript_id"])].copy()

# %%
## Import disease relevant genes
disease_relevant_genes = pd.read_csv("../../references/disease_relevant_gene_names.csv", 
                                     names=["gene_id", "gene_name"], header=0)
## Ad genes
ad_names = pd.read_csv("../../references/AD_genes.csv", sep="\t")
ad_names.dropna(inplace=True)
ad_names.drop_duplicates(inplace=True)

## Concatenate both
disease_relevant_genes = pd.concat([disease_relevant_genes, ad_names]).drop_duplicates()

# %%
## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
orig_ref = pd.read_csv("../../references/CHM13.v2.0.gff3", header=None, delimiter="\t", low_memory=False, 
                       names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"])

# %%
## Create good reference to convert gene names
orig_ref = parse_df_columns(orig_ref, is_ref=True)
orig_ref = orig_ref.loc[orig_ref["type"]=="gene"].copy()

## Take the extra stuff for the version of genes on ENSEMBL ID
orig_ref["gene_id"] = orig_ref["gene_id"].str.split(".", expand=True)[0].copy()

# %%
## Create list of novel transcripts in disease relevant genes
novel_relevant = disease_relevant_genes.merge(orig_ref[["gene_id", "gene_name"]], on=["gene_id", "gene_name"], how="inner")

# %%
## Only keep gene_ids that match, add gene names
novel_relevant = chm13_novel_transcripts_expressed.merge(novel_relevant[["gene_id", "gene_name"]], on=["gene_id"], how="inner")

# %%
## Drop any duplicates
novel_relevant.drop_duplicates(inplace=True)

# %%
## See shape
novel_relevant.shape
# Out:
# (50, 12)

# %%
## Remove MT transcripts
novel_relevant = novel_relevant.loc[novel_relevant["chr"] != "chrM"]

# %%
## Only keep original ensembl ID
chm13_counts_ensembl_id = chm13_counts.copy()
chm13_counts_ensembl_id["gene_id"] = chm13_counts_ensembl_id["gene_id"].str.split(".", expand=True)[0]

# %%
## Merge with medically relevant genes on gene_id and get gene names
novel_relevant_counts = pd.merge(chm13_counts_ensembl_id, novel_relevant[["gene_id", "gene_name"]], on=["gene_id"], how="inner")

# %%
## Drop any duplicates
novel_relevant_counts.drop_duplicates(inplace=True)

# %%
## See shape
novel_relevant_counts.shape
# Out:
# (552, 10)

# %%
## See number of novel transcript left
novel_relevant_counts.loc[novel_relevant_counts["is_novel_transcript"]==True].shape
# Out:
# (51, 10)

# %%
## Calculate relative transcript abundance
novel_relevant_relative_abundance = relative_transcript_abundance(novel_relevant_counts)

# %%
## Create list with med relevant genes with novel isoforms and their relative frequency
novel_relevant_words = novel_relevant_relative_abundance.loc[novel_relevant_relative_abundance["is_novel_transcript"] == True][["gene_name", "relative_abundance_percent"]]

# %%
## Drop duplicates
novel_relevant_words = novel_relevant_words.drop_duplicates()

# %%
## Sum relative abundance of all novel isoforms by gene name and round to nearest integer
novel_relevant_words = round(novel_relevant_words.groupby("gene_name")["relative_abundance_percent"].sum(), 0)

# %%
## Create a dataframe to properly store the data
novel_relevant_word_df = pd.DataFrame()
novel_relevant_word_df['word_count'] = novel_relevant_words
novel_relevant_word_df["gene_name"] = novel_relevant_words.index

# %%
## Drop index
novel_relevant_word_df.reset_index(inplace=True, drop=True)

# %%
## Print genes with novel isoforms relevant to AD
ad_names = pd.read_csv("../../references/AD_genes.csv", sep="\t")
print(novel_relevant_word_df.loc[novel_relevant_word_df["gene_name"].isin(ad_names["gene_name"])])
# Out:
#     word_count gene_name
# 19        34.0  HLA-DQA1
# 44        73.0      WNT3

# %%
## Print relative abundance for a couple other genes
print(novel_relevant_word_df.loc[novel_relevant_word_df["gene_name"].isin(["MAOB", "SLC26A1"])])
# Out:
#     word_count gene_name
# 25         9.0      MAOB
# 36        90.0   SLC26A1

# %%
novel_relevant_word_df
# Out:
#     word_count gene_name
# 0         32.0       ABO
# 1         16.0     ACADM
# 2         21.0      ALAD
# 3         73.0   ALDH1A1
# 4         45.0      ALG3
# 5         33.0      BCAN
# 6         70.0      CA5A
# 7         75.0    CAMKMT
# 8         18.0      CAST
# 9         34.0     CLIC2
# 10        25.0     CPLX2
# 11        32.0     CPT1A
# 12        20.0     DGUOK
# 13        22.0      DPYD
# 14        61.0      DPYS
# 15        21.0     EGLN1
# 16        34.0      FGF9
# 17        79.0      GCDH
# 18        19.0  HLA-DPB1
# 19        34.0  HLA-DQA1
# 20        97.0  HLA-DRB1
# 21        14.0       IVD
# 22        35.0       KHK
# 23        63.0     KIF27
# 24         5.0      LRP4
# 25         9.0      MAOB
# 26        38.0       MFF
# 27        81.0   NDUFAF1
# 28        20.0    NDUFV3
# 29        36.0     NELFA
# 30        30.0     NLRP1
# 31         7.0      NPM1
# 32        19.0      OFD1
# 33        19.0     PBRM1
# 34        55.0       PKM
# 35        11.0     PPP6C
# 36        90.0   SLC26A1
# 37        11.0   SLCO1A2
# 38        10.0    SNAPC5
# 39        46.0     SNTG2
# 40        71.0      TBCE
# 41        21.0    TMEM99
# 42         8.0      TSFM
# 43        50.0     U2AF1
# 44        73.0      WNT3
# 45        25.0      ZIC1
# 46        56.0    ZNF213
# 47        41.0    ZNF429

# %%
## Print number of disease relevant genes with high-confidence novel isoforms
novel_relevant_word_df["gene_name"].nunique()
# Out:
# 48

# %%
## Generate word list with frequency of word being proportional to novel isoform relative abundance
word_list = ""

for i in range(len(novel_relevant_word_df)):
        
    for j in range(int(novel_relevant_word_df.iloc[i][0])):
        word_list = word_list + novel_relevant_word_df.iloc[i][1] + " "

# %%
## Generate wordcloud
word_cloud = WordCloud(collocations=False, font_step=1, background_color='white', regexp=r"\w[\w\-]+", normalize_plurals=False,
            colormap="nipy_spectral", prefer_horizontal=1, include_numbers=True, stopwords=None, random_state=1996,
                      width=20000, height=5000).generate(word_list)

# %%
## Save the in-person poster version (higher DPI) 
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('../../figures/UKY_Neuro_Symposium/word_cloud_in-person.png', dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %% [markdown]
# ###########################################################################################################################

# %%
## Save novel transcript in known genes for GRCh38 so that we can compare them to known trancripts in ENSEMBL tracks
orig_ref = pd.read_csv("../../references/CHM13.v2.0.gff3", header=None, delimiter="\t", low_memory=False, 
                       names=["chr", "source", "type", "start", "end", "dot_1", "strand", "dot_2", "other"])

# %%
## Create good reference to convert gene names
orig_ref = parse_df_columns(orig_ref, is_ref=True)
orig_ref = orig_ref.loc[orig_ref["type"]=="gene"].copy()

# %%
## Only keep gene_ids that match between both
chm13_counts_with_name = chm13_counts.merge(orig_ref[["gene_id", "gene_name"]], on=["gene_id"], how="inner")

# %%
## Drop any duplicates
chm13_counts_with_name.drop_duplicates(inplace=True)

# %%
chm13_counts_with_name["gene_id"] = chm13_counts_with_name["gene_id"].str.split(".", expand=True)[0]

# %%
## Get the gene names in the counts matrix and only keep medically relevant genes
medically_relevant_counts = chm13_counts_with_name.merge(disease_relevant_genes[["gene_id", "gene_name"]], on=["gene_id", "gene_name"], how="inner")

# %%
## Delete duplicates
medically_relevant_counts.drop_duplicates(inplace=True)

# %%
## Remove all isoforms with less than 500 reads in every sample
medically_relevant_counts = medically_relevant_counts[(medically_relevant_counts["total_CPM"]>5)].copy()

# %%
## Only keep genes with more than one "highly expressed" isoforms
dup_gene_names = medically_relevant_counts.loc[medically_relevant_counts.duplicated(subset="gene_id")]

medically_relevant_counts_multiple_iso = medically_relevant_counts.loc[medically_relevant_counts["gene_id"].isin(dup_gene_names["gene_id"])].copy()

# %%
## How many medically relevant isoforms with more than one highly expressed isoforms in one gene
medically_relevant_counts_multiple_iso.shape
# Out:
# (2161, 10)

# %%
## How many highly expressed isoforms are there for each gene?
df_numbers = medically_relevant_counts_multiple_iso["gene_id"].value_counts()

# %%
## How many medically relevant genes have more than one highly expressed isoform?
medically_relevant_counts_multiple_iso["gene_id"].nunique()
# Out:
# 854

# %%
## Display their names
medically_relevant_counts_multiple_iso["gene_name"].unique()
# Out:
# array(['ACADM', 'BCAN', 'EGLN1', 'KHK', 'DGUOK', 'MFF', 'NELFA', 'CAST',
#        'NPM1', 'HLA-DPB1', 'ALDH1A1', 'ALAD', 'PPP6C', 'CPT1A', 'NDUFAF1',
#        'SNAPC5', 'PKM', 'NLRP1', 'WNT3', 'ZNF429', 'NDUFV3', 'U2AF1',
#        'MAOB', 'MT-TQ', 'CPLX2', 'LRP4', 'SKI', 'ERRFI1', 'EPS15',
#        'PDE4DIP', 'ATP2B4', 'GALNT2', 'ANK3', 'SHTN1', 'PC', 'SCN8A',
#        'ZDHHC17', 'SSH1', 'UBE3B', 'ATP2A2', 'MED13L', 'GOLGA3', 'PCDH9',
#        'SEC23A', 'NIN', 'KTN1', 'HSP90AA1', 'DMXL2', 'MYO5A', 'IGF1R',
#        'MEF2A', 'ABR', 'PAFAH1B1', 'LASP1', 'TRIM37', 'LPIN2', 'NPC1',
#        'MBOAT7', 'TRIB2', 'ITSN2', 'FBXO11', 'SPTBN1', 'XPO1', 'SPRED2',
#        'SEMA4C', 'CERS6', 'WIPF1', 'ATF2', 'NCKAP1', 'SF3B1', 'SIRPA',
#        'SLC23A2', 'RIN2', 'TGM2', 'STK4', 'ADNP', 'DYRK1A', 'SREBF2',
#        'DAG1', 'PRICKLE2', 'MYLK', 'KIAA0232', 'PALLD', 'TRIO', 'IL6ST',
#        'SYNPO', 'KCNQ5', 'SOD2', 'TNS3', 'TRRAP', 'KMT2C', 'CTSB', 'PDP1',
#        'PLEC', 'HNRNPK', 'SPTAN1', 'SETX', 'STS', 'UBA1', 'HUWE1',
#        'MAGT1', 'PGK1', 'ACSL4', 'LAMP2', 'XIAP', 'OCRL', 'CD74', 'ERCC1',
#        'GABRA1', 'RB1CC1', 'RNASET2', 'GOPC', 'DCN', 'CIC', 'KIF22',
#        'KCNAB2', 'REEP1', 'KEAP1', 'ASNS', 'ALDH3A2', 'MRPS34', 'SLC25A3',
#        'CTSA', 'DLG3', 'MAP2', 'EPB41L1', 'SPG21', 'MIF', 'XBP1',
#        'SYNGR1', 'ACO2', 'SUPT16H', 'AP4S1', 'APEX1', 'PABPN1', 'ARHGAP5',
#        'EEF1A2', 'WDR13', 'STAG2', 'FMR1', 'PQBP1', 'ARHGEF7', 'USB1',
#        'GDAP1', 'NEFM', 'PNPLA6', 'FCGRT', 'PSENEN', 'FKBP8', 'PON2',
#        'CLIP2', 'AK1', 'VIM', 'SLC25A39', 'GIT1', 'GOSR2', 'DDX5',
#        'KAT2A', 'RANGRF', 'WFS1', 'LDHA', 'CRYAB', 'PPFIBP1', 'TPI1',
#        'C12orf57', 'CRBN', 'BCL6', 'NCK2', 'MPV17', 'RPS15', 'GGCX',
#        'RPL22', 'MFN2', 'HMGCL', 'EEF1B2', 'SGK1', 'SPP1', 'MXI1',
#        'RNF170', 'TARDBP', 'MAPK8IP1', 'CHPF', 'PLCG1', 'PEPD', 'DST',
#        'CDKN1A', 'BBS2', 'C3', 'MAX', 'RALY', 'UROD', 'KLC1', 'ELK1',
#        'COX7C', 'PIN1', 'PNKD', 'HSPB1', 'TST', 'EMC4', 'CALU', 'HBA2',
#        'PCCB', 'RAF1', 'NDUFA2', 'ACTN4', 'NDUFA10', 'ARHGEF9', 'GFAP',
#        'ATP6V1E1', 'COX4I1', 'F12', 'FUS', 'EFR3A', 'IMMT', 'SERPINF1',
#        'SNAP25', 'CHL1', 'SORT1', 'ACP2', 'FOLH1', 'DYSF', 'GPNMB',
#        'CCM2', 'KAT7', 'BIN1', 'FXYD6', 'PREPL', 'ITGAV', 'CCND2', 'HEXB',
#        'CSDE1', 'B9D1', 'MSMO1', 'SLC7A5', 'SREBF1', 'TTC19', 'SCARB1',
#        'PRPF40B', 'PHF3', 'MTUS1', 'MCM4', 'DNAJB6', 'CLCN7', 'MAPT',
#        'KANSL1', 'PITPNM3', 'GNAO1', 'SEC23B', 'TYROBP', 'SCN1B',
#        'PAFAH1B3', 'MAP2K2', 'OPTN', 'SMARCB1', 'EP300', 'BRD4', 'DNAJC6',
#        'ATP2B3', 'FOXRED1', 'SIAE', 'KCNT1', 'CD81', 'TP53BP1', 'EHBP1',
#        'MCOLN1', 'ORC4', 'ARID4B', 'ECE1', 'YWHAE', 'ANK2', 'CUL3',
#        'GLRB', 'RAP1GDS1', 'THRA', 'SMARCE1', 'NNT', 'MTRR', 'ADD1',
#        'SDHA', 'MAP3K13', 'MGLL', 'RAB7A', 'FBXW11', 'SLC1A3', 'NBN',
#        'NRXN2', 'MGST2', 'LARS2', 'AHI1', 'GNAS', 'NSMF', 'ADAM22',
#        'LZTS1', 'HNRNPH3', 'CPEB3', 'DAXX', 'GNAI2', 'FBXO7', 'DNM1L',
#        'PEX5', 'SUOX', 'ERBB3', 'DIABLO', 'ETFA', 'TPM1', 'MFGE8', 'ABAT',
#        'FTO', 'UQCRC2', 'SPG7', 'NCOR1', 'G6PC3', 'CLTC', 'DTNA', 'DYM',
#        'SH3GL1', 'SOD1', 'TPM3', 'ACP1', 'RPL21', 'CALM2', 'RPS27A',
#        'SLC4A10', 'UNC80', 'FTH1', 'NICN1', 'MEGF10', 'ARHGAP26', 'NHP2',
#        'QKI', 'NLGN4X', 'NONO', 'RSPO2', 'NDUFB9', 'NTRK2', 'CIZ1',
#        'SERPING1', 'ROM1', 'BSCL2', 'CNKSR2', 'PTS', 'USP15', 'THRB',
#        'NRXN3', 'QDPR', 'CACNB2', 'PPM1B', 'NADK2', 'GPD1L', 'TIA1',
#        'LIPA', 'HNRNPU', 'SCN3A', 'SCN2A', 'JAZF1', 'MSI2', 'UCHL1',
#        'LY96', 'ERCC3', 'TMEM237', 'KIF5A', 'ADK', 'TSPAN7', 'UQCRB',
#        'KAT6B', 'AIFM1', 'SLC6A1', 'DMD', 'NCOA1', 'OBSL1', 'IFNGR2',
#        'ALDH4A1', 'CBFB', 'CALM3', 'ST6GALNAC6', 'TNNT1', 'ETHE1',
#        'SYNGAP1', 'NCKIPSD', 'AZIN2', 'BOLA3', 'CHN1', 'ATP1A1', 'IGFBP7',
#        'TGFBR2', 'TUBA1A', 'SERPINI1', 'RSRC1', 'SYN1', 'GYG1', 'PPP1CB',
#        'LZTFL1', 'ETNPPL', 'NDUFAF2', 'NDUFS4', 'HSPA9', 'COX6C', 'CFL2',
#        'LRRK2', 'GABRB3', 'PCBD1', 'SCN3B', 'ILK', 'TPP1', 'COG1', 'NAB2',
#        'STAT6', 'HERPUD1', 'COQ4', 'CRK', 'STIM1', 'PRRT2', 'VKORC1',
#        'TPM4', 'UNC119', 'SPINT2', 'ANGPTL4', 'SDHAF2', 'SMARCA2',
#        'KCNAB1', 'ITPR1', 'CTNNA1', 'DLG4', 'POLR1D', 'RFXANK', 'HCN1',
#        'MECP2', 'SCN1A', 'BTD', 'AUH', 'CAMTA1', 'ZEB2', 'NFU1', 'CHCHD7',
#        'REPS2', 'HINT1', 'TMEM126A', 'MAP6', 'PRPF8', 'GAP43', 'ST3GAL5',
#        'GFRA2', 'GPS1', 'FIP1L1', 'USP8', 'BCL2L1', 'RNASEH2C', 'SEZ6L2',
#        'NDUFA11', 'ZHX3', 'ETFB', 'EEF1A1', 'B4GALT2', 'ATP5MD', 'SPTBN2',
#        'SNCB', 'LGI4', 'CTSF', 'NBEA', 'GPD2', 'MRPL48', 'MRPS22',
#        'MAPK10', 'HDLBP', 'RPL38', 'HRAS', 'KRT17', 'GLUL', 'RABL6',
#        'MLC1', 'AQP1', 'COMMD1', 'RPS14', 'MEN1', 'BANF1', 'TMEM70',
#        'PMP22', 'STX16', 'PFKM', 'MED25', 'CADPS2', 'NDUFS8', 'PITPNA',
#        'OSBPL2', 'FAM20C', 'BTBD9', 'ASAH1', 'SPECC1L', 'SULT1A1', 'CD55',
#        'TNIP1', 'ST8SIA5', 'GPHN', 'CDC42', 'CD200', 'ABCD3', 'RPL5',
#        'TFE3', 'KCNA2', 'CLU', 'SLC9A9', 'PANK2', 'NSD3', 'MSRA', 'NTRK3',
#        'CAPN3', 'GRHPR', 'BBS1', 'A2M', 'FOXP1', 'TALDO1', 'ARID1B',
#        'B4GALT3', 'SLC25A22', 'KIF1A', 'NQO1', 'PIK3R1', 'HBA1', 'PINK1',
#        'PRKCB', 'SLC14A1', 'CRTC1', 'CD151', 'SET', 'ROGDI', 'NDUFV1',
#        'CD46', 'ACADVL', 'PPP3CA', 'HIF1A', 'C19orf12', 'NDRG1',
#        'SNRNP200', 'FN1', 'EIF4A2', 'LARP7', 'PSEN1', 'SCN4B', 'CEP57',
#        'PRKRA', 'CRELD1', 'PEG3', 'ATP13A2', 'DKK3', 'GBA', 'JMJD1C',
#        'NDUFA12', 'COL4A5', 'ATP2C1', 'COA5', 'GALNT9', 'RPL35A', 'RBM10',
#        'ANKS1B', 'NOP56', 'NDUFB1', 'PEX26', 'SV2B', 'CHD3', 'DDX41',
#        'SULT4A1', 'EWSR1', 'NRXN1', 'FBXW4', 'GLRX5', 'DGCR6', 'CADM1',
#        'BGN', 'OPCML', 'DPP6', 'CSGALNACT1', 'BRWD1', 'BSG', 'PCLO',
#        'NF2', 'HBB', 'WASF3', 'GABRA5', 'NPAS2', 'BCL11A', 'SLC44A2',
#        'ZFP36L1', 'FGFR2', 'DNAJB2', 'CUL4B', 'PPP2R2B', 'SNCA',
#        'AGTPBP1', 'EZR', 'RAD51C', 'EBAG9', 'ELAC2', 'SHANK2', 'SNX10',
#        'PARK7', 'DTNBP1', 'USP9Y', 'ABHD12', 'DOCK9', 'SRSF3', 'PRMT7',
#        'NUDT1', 'USP1', 'MEF2C', 'ATXN3', 'IDS', 'B4GALNT1', 'DNM1',
#        'DPM3', 'SYNE1', 'MPC1', 'FHIT', 'SMPD1', 'NR3C2', 'SMAD4',
#        'CTNNA2', 'AFDN', 'GAD1', 'DROSHA', 'POMGNT2', 'RPS10', 'RPL10',
#        'USP7', 'HSPD1', 'BCAP31', 'PRICKLE1', 'RNF6', 'NNAT', 'UBE2A',
#        'SNRPN', 'DDIT3', 'APP', 'ABI1', 'PSAT1', 'RPL36', 'CLCN3',
#        'CNTN1', 'RGS7', 'ARID4A', 'B2M', 'AKT1', 'CTNNB1', 'DOC2A',
#        'LDHB', 'GRIN1', 'CD59', 'NRCAM', 'NUMA1', 'ATP2B2', 'ASS1',
#        'TBL1XR1', 'BCLAF1', 'MAP2K4', 'HSP90AB1', 'PLTP', 'ATG7', 'TCF4',
#        'HNRNPA2B1', 'SND1', 'AK2', 'PTPRD', 'RYR1', 'MRTFA', 'DNM2',
#        'FNBP1', 'MLF1', 'SLC25A46', 'PPIA', 'GABBR1', 'NF1', 'PICALM',
#        'GPI', 'GABRA2', 'GABRG2', 'ATN1', 'FDPS', 'NACA', 'RAB18', 'CHD4',
#        'PEX2', 'DCTD', 'SFPQ', 'FKBP5', 'NFE2L1', 'CACNA1E', 'STMN1',
#        'SRSF2', 'ATL1', 'GSTK1', 'STAT4', 'NFIX', 'PRKAR1A', 'ZBTB18',
#        'TTC37', 'XRCC6', 'PCNT', 'TRAPPC2', 'TFRC', 'DYNC1H1', 'SRGAP3',
#        'SQSTM1', 'RPS24', 'SOX10', 'STAT1', 'OPA1', 'ATP1A2', 'MOCS2',
#        'KIF21A', 'MYBPC1', 'L1CAM', 'CNTNAP2', 'DCTN1', 'SMOC1', 'ACTN2',
#        'SNRPE', 'PCMT1', 'CITED2', 'ATP1B1', 'TMCO1', 'MGST3', 'NDUFS2',
#        'USF1', 'PEX19', 'LAMTOR2', 'ADAR', 'TSPYL1', 'UROS', 'OAT',
#        'HTRA1', 'SEC63', 'VPS45', 'PHGDH', 'SLC16A1', 'GSTO1', 'NAA10',
#        'EXTL2', 'BTRC', 'LMO4', 'FHL1', 'SLC9A6', 'DHCR24', 'LGI1',
#        'SCP2', 'MAN1B1', 'SURF1', 'POMGNT1', 'RALGDS', 'SLC2A1', 'PPT1',
#        'MRPS16', 'CCND3', 'STXBP1', 'COX7B', 'ATRX', 'GIGYF2', 'GSN',
#        'RPL11', 'BRD2', 'PSMB8', 'IQSEC2', 'ACBD5', 'DDX39B', 'HLA-C',
#        'FLOT1', 'HLA-A', 'CST3', 'KCNC3', 'SLITRK1', 'SPRY2', 'TRIM27',
#        'EDNRB', 'NDUFAF5', 'GBA2', 'KIAA0319', 'APRT', 'ATP6AP2', 'ITM2B',
#        'UQCRQ', 'SAT1', 'E2F4', 'PRNP', 'FRY', 'SERPINB6', 'FRMPD4',
#        'PSIP1', 'IDH3B', 'NT5C3A', 'FKBP1A', 'TUSC3', 'DNAJC19', 'AQP4',
#        'KCNQ3', 'STK38L', 'ATXN2', 'PTPRN2', 'TFPT', 'XRCC5', 'CRLF1',
#        'PDCD10', 'SERPINA3', 'SLC35G2', 'RPL24', 'CHD2', 'MATR3', 'POR',
#        'PSAP', 'ALDOA', 'ZNF365', 'GNE', 'GATM', 'NFE2L2', 'CHMP1A',
#        'MEG3', 'GSTP1', 'DDX3X', 'HSF1', 'HDAC9', 'EFTUD2', 'TF',
#        'FAM131B', 'HLA-B', 'MIAT', 'ACTB', 'HSD17B4', 'GDI1', 'SGCE',
#        'PTPRJ', 'GPX1', 'MMAB', 'PLP1', 'CNBP', 'SYN2', 'EIF2B5', 'TREX1',
#        'LSM14A', 'ATP1A3', 'PET100', 'GRIA3', 'PEG10', 'AGK', 'NDUFA6',
#        'GCLC', 'SRP72', 'MALAT1', 'DDX6', 'KIRREL3', 'RDX', 'C1R',
#        'MTHFD1', 'TBC1D24', 'ACTG1', 'RPL26', 'PRKCSH', 'APOC1'],
#       dtype=object)

# %%
## Display number of isoforms for key genes I am interested in
medically_relevant_counts_multiple_iso.loc[medically_relevant_counts_multiple_iso["gene_name"].isin(["MAPT", "APP", "SNCA", "PARK7", "PINK1"])]["gene_name"].value_counts()
# Out:
# SNCA     6
# APP      4
# MAPT     3
# PINK1    2
# PARK7    2
# Name: gene_name, dtype: int64

# %%
## Display number of isoforms for key genes I am interested in
medically_relevant_counts_multiple_iso.loc[medically_relevant_counts_multiple_iso["gene_id"].isin(ad_names["gene_id"])]["gene_name"].value_counts()
# Out:
# CTSB     6
# BIN1     4
# CLU      4
# APP      4
# COX7C    3
# WNT3     2
# ANK3     2
# NCK2     2
# SORT1    2
# JAZF1    2
# TNIP1    2
# DOC2A    2
# Name: gene_name, dtype: int64

# %%
## Display number of isoforms for key genes for all
medically_relevant_counts_multiple_iso["gene_name"].value_counts()
# Out:
# DTNA          10
# CRYAB         10
# GNAS           9
# RPS24          8
# SNRPN          7
# ACTB           7
# FDPS           6
# PKM            6
# SNCA           6
# ABI1           6
# CHN1           6
# CTSB           6
# MAPK10         6
# ANK2           6
# ALDOA          6
# KCNAB2         6
# HNRNPA2B1      6
# CALM3          5
# NDRG1          5
# GRIN1          5
# NDUFB1         5
# CALM2          5
# SPTAN1         5
# SLC25A3        5
# UQCRQ          5
# PSIP1          5
# MEG3           5
# MATR3          5
# HNRNPK         5
# CCND3          5
# PCMT1          5
# UCHL1          5
# COX4I1         5
# GRHPR          5
# FIP1L1         5
# KIF5A          5
# SOD2           5
# NACA           4
# MGLL           4
# GLUL           4
# SERPINB6       4
# LAMP2          4
# ADD1           4
# RPL38          4
# PRMT7          4
# ABHD12         4
# SFPQ           4
# HDLBP          4
# COX6C          4
# STXBP1         4
# DST            4
# BCAN           4
# UROD           4
# KLC1           4
# HSPB1          4
# SGK1           4
# MFN2           4
# SLC44A2        4
# TPI1           4
# DCTN1          4
# BIN1           4
# RPL35A         4
# FKBP8          4
# PREPL          4
# NEFM           4
# MOCS2          4
# HLA-C          4
# PPP2R2B        4
# HLA-A          4
# SPTBN2         4
# ILK            4
# SCN3B          4
# BANF1          4
# CAMTA1         4
# PMP22          4
# NDUFB9         4
# MYO5A          4
# SYNE1          4
# NRCAM          4
# CD59           4
# PPP3CA         4
# FTH1           4
# PDE4DIP        4
# CTNNB1         4
# QKI            4
# NTRK2          4
# PAFAH1B1       4
# CLU            4
# CTNNA2         4
# UQCRB          4
# BSCL2          4
# SNAPC5         4
# APP            4
# NPM1           4
# DGUOK          4
# RPL26          4
# FAM131B        4
# CNBP           4
# DNM1           4
# FBXO7          4
# EIF4A2         4
# ST6GALNAC6     4
# SPTBN1         4
# UNC119         3
# TUBA1A         3
# IMMT           3
# HNRNPH3        3
# SNAP25         3
# ACTN2          3
# FGFR2          3
# RAB7A          3
# DYSF           3
# FUS            3
# DNAJB2         3
# CLCN3          3
# DNM2           3
# CCM2           3
# MYBPC1         3
# SERPINI1       3
# SDHA           3
# FXYD6          3
# CNKSR2         3
# THRA           3
# SLC1A3         3
# EMC4           3
# SCN2A          3
# MEF2C          3
# PPIA           3
# HNRNPU         3
# UROS           3
# COX7C          3
# GABBR1         3
# HBB            3
# PPM1B          3
# PTPRD          3
# CTNNA1         3
# NDUFA2         3
# QDPR           3
# NDUFA10        3
# ARHGEF9        3
# GFAP           3
# SMARCA2        3
# GPI            3
# B2M            3
# HEXB           3
# CCND2          3
# TYROBP         3
# PRKAR1A        3
# CFL2           3
# BRWD1          3
# CLTC           3
# ATP2B2         3
# DNAJC6         3
# TBL1XR1        3
# NFE2L1         3
# FKBP5          3
# TNNT1          3
# ARID4B         3
# PPP1CB         3
# YWHAE          3
# DPM3           3
# MAP2K4         3
# CUL3           3
# TPM1           3
# PAFAH1B3       3
# TPM3           3
# HSP90AB1       3
# GNAO1          3
# CSDE1          3
# B9D1           3
# OBSL1          3
# PRRT2          3
# B4GALNT1       3
# RSRC1          3
# UNC80          3
# TTC19          3
# SLC4A10        3
# LDHB           3
# COQ4           3
# ATP1A1         3
# HERPUD1        3
# ACP1           3
# DNAJB6         3
# MAPT           3
# EBAG9          3
# APOC1          3
# USP7           3
# BBS2           3
# UBA1           3
# SHTN1          3
# PGK1           3
# ATP2C1         3
# OCRL           3
# CD74           3
# ERCC1          3
# CDC42          3
# GABRA1         3
# ROGDI          3
# TREX1          3
# GOPC           3
# ATP1A3         3
# DCN            3
# CIC            3
# KEAP1          3
# RPL5           3
# ATP6AP2        3
# MRPS34         3
# CTSA           3
# DLG3           3
# MAP2           3
# CPLX2          3
# SNCB           3
# FRMPD4         3
# IDH3B          3
# SLC14A1        3
# FKBP1A         3
# DDX3X          3
# TRIM37         3
# HIF1A          3
# MEF2A          3
# SULT1A1        3
# MIAT           3
# KTN1           3
# ATF2           3
# PSAP           3
# HSD17B4        3
# CRELD1         3
# PCDH9          3
# RPS14          3
# ATP13A2        3
# GDI1           3
# SGCE           3
# ACADVL         3
# PTPRN2         3
# IL6ST          3
# SYNPO          3
# PC             3
# DNAJC19        3
# KMT2C          3
# MIF            3
# MBOAT7         3
# ATP5MD         3
# NRXN1          3
# RANGRF         3
# DGCR6          3
# C12orf57       3
# CRBN           3
# SCP2           3
# LGI1           3
# RPS15          3
# GGCX           3
# SLC9A6         3
# FHL1           3
# CAST           3
# EEF1B2         3
# SPP1           3
# RPL10          3
# BTRC           3
# ACTG1          3
# EXTL2          3
# MFF            3
# GSTO1          3
# NFU1           3
# PRKCSH         3
# RALGDS         3
# MAP6           3
# COX7B          3
# RPL11          3
# CHD3           3
# PQBP1          3
# MSRA           3
# BCL2L1         3
# DDX39B         3
# SULT4A1        3
# HBA1           3
# CST3           3
# EEF1A1         3
# GIGYF2         3
# PON2           3
# EWSR1          3
# NDUFV3         3
# PRKCB          2
# SNRNP200       2
# DROSHA         2
# PINK1          2
# C19orf12       2
# RPS10          2
# NR3C2          2
# SMPD1          2
# POMGNT2        2
# SLC25A22       2
# CD151          2
# MPC1           2
# PIK3R1         2
# CD46           2
# NDUFV1         2
# GAD1           2
# FHIT           2
# SET            2
# KIF1A          2
# NQO1           2
# CRTC1          2
# AFDN           2
# SMAD4          2
# SRSF3          2
# FN1            2
# GLRX5          2
# ANKS1B         2
# RAD51C         2
# EZR            2
# AGTPBP1        2
# NOP56          2
# PEX26          2
# SV2B           2
# DDX41          2
# CUL4B          2
# FBXW4          2
# ZFP36L1        2
# LARP7          2
# CADM1          2
# BGN            2
# BCL11A         2
# NPAS2          2
# GABRA5         2
# WASF3          2
# NF2            2
# PCLO           2
# DPP6           2
# CSGALNACT1     2
# RBM10          2
# ELAC2          2
# SHANK2         2
# SNX10          2
# PSEN1          2
# SCN4B          2
# CEP57          2
# IDS            2
# ATXN3          2
# PRKRA          2
# PEG3           2
# DKK3           2
# USP1           2
# NUDT1          2
# GBA            2
# JMJD1C         2
# NDUFA12        2
# COL4A5         2
# BSG            2
# DOCK9          2
# COA5           2
# GALNT9         2
# USP9Y          2
# DTNBP1         2
# PARK7          2
# OPCML          2
# STAT4          2
# HSPD1          2
# FRY            2
# GBA2           2
# KIAA0319       2
# APRT           2
# ITM2B          2
# SAT1           2
# E2F4           2
# PRNP           2
# NT5C3A         2
# PDCD10         2
# TUSC3          2
# AQP4           2
# KCNQ3          2
# STK38L         2
# ATXN2          2
# TFPT           2
# XRCC5          2
# NDUFAF5        2
# EDNRB          2
# TRIM27         2
# SPRY2          2
# MAN1B1         2
# SURF1          2
# POMGNT1        2
# SLC2A1         2
# PPT1           2
# MRPS16         2
# ATRX           2
# GSN            2
# BRD2           2
# PSMB8          2
# IQSEC2         2
# ACBD5          2
# FLOT1          2
# KCNC3          2
# SLITRK1        2
# CRLF1          2
# SERPINA3       2
# LMO4           2
# GCLC           2
# EIF2B5         2
# LSM14A         2
# PET100         2
# GRIA3          2
# PEG10          2
# AGK            2
# NDUFA6         2
# SRP72          2
# SLC35G2        2
# MALAT1         2
# DDX6           2
# KIRREL3        2
# RDX            2
# C1R            2
# MTHFD1         2
# TBC1D24        2
# SYN2           2
# PLP1           2
# MMAB           2
# GPX1           2
# RPL24          2
# CHD2           2
# POR            2
# ZNF365         2
# GNE            2
# GATM           2
# NFE2L2         2
# CHMP1A         2
# GSTP1          2
# HSF1           2
# HDAC9          2
# EFTUD2         2
# TF             2
# HLA-B          2
# PTPRJ          2
# DHCR24         2
# NAA10          2
# BCAP31         2
# PICALM         2
# AK2            2
# RYR1           2
# MRTFA          2
# FNBP1          2
# MLF1           2
# SLC25A46       2
# NF1            2
# GABRA2         2
# SRSF2          2
# GABRG2         2
# ATN1           2
# RAB18          2
# CHD4           2
# PEX2           2
# DCTD           2
# CACNA1E        2
# SND1           2
# TCF4           2
# ATG7           2
# PLTP           2
# PRICKLE1       2
# RNF6           2
# NNAT           2
# UBE2A          2
# DDIT3          2
# PSAT1          2
# RPL36          2
# CNTN1          2
# RGS7           2
# ARID4A         2
# AKT1           2
# DOC2A          2
# NUMA1          2
# ASS1           2
# BCLAF1         2
# STMN1          2
# ATL1           2
# SLC16A1        2
# PEX19          2
# SNRPE          2
# CITED2         2
# ATP1B1         2
# TMCO1          2
# MGST3          2
# NDUFS2         2
# USF1           2
# LAMTOR2        2
# GSTK1          2
# ADAR           2
# TSPYL1         2
# OAT            2
# HTRA1          2
# SEC63          2
# VPS45          2
# PHGDH          2
# SMOC1          2
# CNTNAP2        2
# L1CAM          2
# KIF21A         2
# ARID1B         2
# NFIX           2
# ZBTB18         2
# TTC37          2
# XRCC6          2
# PCNT           2
# TRAPPC2        2
# TFRC           2
# DYNC1H1        2
# SRGAP3         2
# SQSTM1         2
# SOX10          2
# STAT1          2
# OPA1           2
# ATP1A2         2
# B4GALT3        2
# ACADM          2
# TALDO1         2
# MXI1           2
# WFS1           2
# LDHA           2
# PPFIBP1        2
# BCL6           2
# NCK2           2
# MPV17          2
# RPL22          2
# HMGCL          2
# RNF170         2
# ELK1           2
# TARDBP         2
# MAPK8IP1       2
# CHPF           2
# PLCG1          2
# PEPD           2
# CDKN1A         2
# C3             2
# MAX            2
# KAT2A          2
# DDX5           2
# GOSR2          2
# GIT1           2
# APEX1          2
# PABPN1         2
# ARHGAP5        2
# EEF1A2         2
# WDR13          2
# STAG2          2
# FMR1           2
# ARHGEF7        2
# USB1           2
# GDAP1          2
# PNPLA6         2
# FCGRT          2
# PSENEN         2
# CLIP2          2
# AK1            2
# VIM            2
# SLC25A39       2
# RALY           2
# PIN1           2
# SUPT16H        2
# SCN1B          2
# PRPF40B        2
# PHF3           2
# MTUS1          2
# MCM4           2
# CLCN7          2
# KANSL1         2
# PITPNM3        2
# SEC23B         2
# MAP2K2         2
# PNKD           2
# OPTN           2
# SMARCB1        2
# EP300          2
# BRD4           2
# ATP2B3         2
# FOXRED1        2
# SIAE           2
# KCNT1          2
# SCARB1         2
# SREBF1         2
# SLC7A5         2
# MSMO1          2
# TST            2
# CALU           2
# HBA2           2
# PCCB           2
# RAF1           2
# ACTN4          2
# ATP6V1E1       2
# F12            2
# EFR3A          2
# SERPINF1       2
# CHL1           2
# SORT1          2
# ACP2           2
# FOLH1          2
# GPNMB          2
# KAT7           2
# ITGAV          2
# AP4S1          2
# ACO2           2
# FOXP1          2
# SEC23A         2
# ANK3           2
# SCN8A          2
# ZDHHC17        2
# SSH1           2
# UBE3B          2
# ATP2A2         2
# MED13L         2
# GOLGA3         2
# NIN            2
# FBXO11         2
# HSP90AA1       2
# DMXL2          2
# IGF1R          2
# ABR            2
# LASP1          2
# LPIN2          2
# NPC1           2
# TRIB2          2
# GALNT2         2
# ATP2B4         2
# EPS15          2
# ERRFI1         2
# EGLN1          2
# KHK            2
# NELFA          2
# HLA-DPB1       2
# ALDH1A1        2
# ALAD           2
# PPP6C          2
# CPT1A          2
# NDUFAF1        2
# NLRP1          2
# WNT3           2
# ZNF429         2
# U2AF1          2
# MAOB           2
# MT-TQ          2
# LRP4           2
# SKI            2
# ITSN2          2
# XPO1           2
# SYNGR1         2
# XIAP           2
# TRRAP          2
# PDP1           2
# PLEC           2
# SETX           2
# STS            2
# HUWE1          2
# MAGT1          2
# ACSL4          2
# RB1CC1         2
# SPRED2         2
# RNASET2        2
# KIF22          2
# REEP1          2
# ASNS           2
# ALDH3A2        2
# EPB41L1        2
# SPG21          2
# XBP1           2
# TNS3           2
# KCNQ5          2
# TRIO           2
# PALLD          2
# SEMA4C         2
# CERS6          2
# WIPF1          2
# NCKAP1         2
# SF3B1          2
# SIRPA          2
# SLC23A2        2
# RIN2           2
# TGM2           2
# STK4           2
# ADNP           2
# DYRK1A         2
# SREBF2         2
# DAG1           2
# PRICKLE2       2
# MYLK           2
# KIAA0232       2
# CD81           2
# TP53BP1        2
# EHBP1          2
# TMEM126A       2
# HCN1           2
# MECP2          2
# BTD            2
# AUH            2
# ZEB2           2
# CHCHD7         2
# REPS2          2
# HINT1          2
# PRPF8          2
# ETFB           2
# GAP43          2
# ST3GAL5        2
# GFRA2          2
# GPS1           2
# USP8           2
# RNASEH2C       2
# SEZ6L2         2
# NDUFA11        2
# RFXANK         2
# POLR1D         2
# DLG4           2
# ITPR1          2
# NDUFS4         2
# HSPA9          2
# LRRK2          2
# GABRB3         2
# PCBD1          2
# TPP1           2
# COG1           2
# NAB2           2
# STAT6          2
# CRK            2
# STIM1          2
# VKORC1         2
# TPM4           2
# SPINT2         2
# ANGPTL4        2
# SDHAF2         2
# KCNAB1         2
# ZHX3           2
# B4GALT2        2
# MCOLN1         2
# ABCD3          2
# BTBD9          2
# ASAH1          2
# SPECC1L        2
# CD55           2
# TNIP1          2
# ST8SIA5        2
# GPHN           2
# CD200          2
# TFE3           2
# LGI4           2
# KCNA2          2
# SLC9A9         2
# PANK2          2
# NSD3           2
# NTRK3          2
# CAPN3          2
# BBS1           2
# A2M            2
# FAM20C         2
# OSBPL2         2
# PITPNA         2
# NDUFS8         2
# CTSF           2
# NBEA           2
# GPD2           2
# MRPL48         2
# MRPS22         2
# HRAS           2
# KRT17          2
# RABL6          2
# MLC1           2
# AQP1           2
# COMMD1         2
# MEN1           2
# TMEM70         2
# STX16          2
# PFKM           2
# MED25          2
# CADPS2         2
# NDUFAF2        2
# ETNPPL         2
# LZTFL1         2
# UQCRC2         2
# PEX5           2
# SUOX           2
# ERBB3          2
# DIABLO         2
# ETFA           2
# MFGE8          2
# ABAT           2
# FTO            2
# SPG7           2
# GYG1           2
# NCOR1          2
# G6PC3          2
# DYM            2
# SH3GL1         2
# SOD1           2
# RPL21          2
# RPS27A         2
# NICN1          2
# DNM1L          2
# GNAI2          2
# DAXX           2
# CPEB3          2
# ORC4           2
# ECE1           2
# GLRB           2
# RAP1GDS1       2
# SMARCE1        2
# NNT            2
# MTRR           2
# MAP3K13        2
# FBXW11         2
# NBN            2
# NRXN2          2
# MGST2          2
# LARS2          2
# AHI1           2
# NSMF           2
# ADAM22         2
# LZTS1          2
# MEGF10         2
# ARHGAP26       2
# NHP2           2
# TMEM237        2
# TSPAN7         2
# KAT6B          2
# AIFM1          2
# SLC6A1         2
# DMD            2
# NCOA1          2
# IFNGR2         2
# ALDH4A1        2
# CBFB           2
# ETHE1          2
# SYNGAP1        2
# NCKIPSD        2
# AZIN2          2
# BOLA3          2
# IGFBP7         2
# TGFBR2         2
# SYN1           2
# ADK            2
# ERCC3          2
# NLGN4X         2
# LY96           2
# NONO           2
# RSPO2          2
# CIZ1           2
# SERPING1       2
# ROM1           2
# PTS            2
# USP15          2
# THRB           2
# NRXN3          2
# CACNB2         2
# NADK2          2
# GPD1L          2
# TIA1           2
# LIPA           2
# SCN3A          2
# JAZF1          2
# MSI2           2
# SCN1A          2
# Name: gene_name, dtype: int64

# %%
## How many highly expressed isoforms are there for each gene?
df_numbers = medically_relevant_counts_multiple_iso["gene_name"].value_counts()

# %%
medically_relevant_counts_multiple_iso['Number of Isoforms'] = medically_relevant_counts_multiple_iso['gene_id'].copy().map(medically_relevant_counts_multiple_iso['gene_id'].value_counts())

# %%
medically_relevant_counts_multiple_iso.drop_duplicates(inplace=True, subset="gene_id")

# %%
medically_relevant_counts_multiple_iso.head()
# Out:
#    transcript_id          gene_id  cshl_356_uky_CPM  cshl_1304_uky_CPM  \
# 0          tx.20  ENSG00000117054              0.91               0.88
# 25         tx.45  ENSG00000132692             39.93              37.62
# 34         tx.62  ENSG00000135766              1.58               9.12
# 75         tx.81  ENSG00000138030              5.21               6.35
# 93         tx.96  ENSG00000114956             17.47              17.87
#
#     cshl_1271_uky_CPM  cshl_1291_uky_CPM  total_CPM is_novel_transcript  \
# 0               17.78               2.74       5.87                True
# 25              40.00              25.46      36.14                True
# 34              12.55               3.34       7.15                True
# 75               8.82               4.91       6.46                True
# 93              43.03              11.36      23.20                True
#
#    is_novel_gene gene_name  Number of Isoforms
# 0          False     ACADM                   2
# 25         False      BCAN                   4
# 34         False     EGLN1                   2
# 75         False       KHK                   2
# 93         False     DGUOK                   4

# %%
medically_relevant_counts_multiple_iso = medically_relevant_counts_multiple_iso.loc[medically_relevant_counts_multiple_iso["Number of Isoforms"] <= 6]

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 12,8
rcParams.update({'font.size': 28})
rcParams['axes.linewidth'] = 6

# %%
sns.countplot(x="Number of Isoforms", data=medically_relevant_counts_multiple_iso, palette="nipy_spectral")
sns.despine()
plt.ylabel("Number of Genes")
plt.savefig('../../figures/UKY_Neuro_Symposium/multiple_isoforms_in-person.png', dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
exclusive_chm13 = pd.read_csv("../../references/CHM13_novel_genes_isoseq.csv")

# %%
exclusive_chm13.head()
# Out:
#            GENEID
# 0  CHM13_G0002360
# 1  CHM13_G0002906
# 2  CHM13_G0003812
# 3  CHM13_G0006285
# 4  CHM13_G0007830

# %%
exclusive_chm13_counts = chm13_counts.loc[chm13_counts["gene_id"].isin(exclusive_chm13['GENEID'])].copy()

# %%
exclusive_chm13_counts.drop(columns=["is_novel_gene", "is_novel_transcript"], inplace=True)

exclusive_chm13_counts["Label"] = "T2T Genes"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 exclusive_chm13_counts.drop(columns=["is_novel_gene", "is_novel_transcript"], inplace=True)
#       3 exclusive_chm13_counts["Label"] = "T2T Genes"
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/.conda/envs/cdna_comparison/lib/python3.10/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['is_novel_gene', 'is_novel_transcript'] not found in axis"

# %%
#chm13_novel_genes.drop(columns=["is_novel_transcript", "is_novel_gene"], inplace=True)

chm13_novel_genes["Label"] = "New Genes"

# %%
all_novel_genes = pd.concat([chm13_novel_genes, exclusive_chm13_counts])

# %%
all_novel_genes = all_novel_genes[(all_novel_genes["total_CPM"]>1)]

# %%
all_novel_genes.shape
# Out:
# (89, 8)

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 8,12
rcParams.update({'font.size': 28})
rcParams['axes.linewidth'] = 6

# %%
fig, ax1 = plt.subplots()
ax1.yaxis.set_ticks_position("right")
ax1.yaxis.tick_right()
ax1.yaxis.set_label_position("right")

sns.countplot(x="Label", data=all_novel_genes, palette="nipy_spectral", ax=ax1)

plt.ylabel("Number of Genes", rotation=270, labelpad=40)
plt.xlabel("", labelpad=4)
sns.despine(right=False, left=True, top=True, bottom=False)

plt.savefig('../../figures/UKY_Neuro_Symposium/novel_genes_in-person.png', dpi=300, transparent=True, bbox_inches="tight")
plt.show()
