# %%
## Import Libraries
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import openpyxl

pd.set_option("max_colwidth", None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
'''
function name: parse_df_columns

purpose: parsing the last aggregate column of the gtf/gff3 into useful columns and cleaning non-relevant columns

input: dataframe containining "raw" gtf/gff

output: dataframe containing gtf with useful columns ["gene_id", "transcript_id", etc...]
'''

def parse_df_columns(df, is_ref=True):

    if is_ref:

        ## Get gene ids
        df["gene_id"] = df["other"].str.split("source_gene=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Get gene names
        df["gene_name"] = df["other"].str.split("source_gene_common_name=", expand=True)[1].str.split(';', expand=True)[0]
        
        ## Only keep relevant
        df = df[["chr", "gene_id", "gene_name"]].copy()

        ## Drop duplicates
        df.drop_duplicates(inplace=True)
        

    else:

        ## Get CHM gene ids
        df["gene_id"] = df["other"].str.split('";', expand=True)[0].str.extract("([^ \"]*$)", expand=True)

        ## Drop "other" column
        df = df[["chr", "gene_id"]].copy()
        
    for col in df.columns:
        df.loc[df[col].isnull(), col] = np.NaN
        

    return df

# %%
'''
function name: calculate_cpm

purpose: Calculate CPM for the each sample given

input: Counts dataset

output: Counts dataset with CPM columns as well
'''

def calculate_cpm(df):

    ## Loop through counts columns to calculate CPM and add to the dataframe
    for col in ["total_counts"]:
        
        df[col] = round(df[col], 2)
        cpm_name = "average_CPM"
        df[cpm_name] = round(((df[col]/(df[col].sum())) * 1000000), 2)
    
    return df

# %%
## Import transcripts
df_transcripts = pd.read_csv("../../data/raw/merged_uky_cshl_GRCh38-107_discovery/bambu_discovery/counts_transcript.txt",
        sep="\t", low_memory=False, header=0)

# %%
## Import Genes
df_genes = pd.read_csv("../../data/raw/merged_uky_cshl_GRCh38-107_discovery/bambu_discovery/counts_gene.txt",
        sep="\t", low_memory=False, header=0)

# %%
## Get total counts for genes and transcripts
df_genes["total_counts"] = df_genes[df_genes.columns[1:]].sum(axis=1)
df_transcripts["total_counts"] = df_transcripts[df_transcripts.columns[2:]].sum(axis=1)

# %%
## Get average counts for genes and transcripts
df_genes["average_counts"] = df_genes["total_counts"]/4
df_transcripts["average_counts"] = df_transcripts["total_counts"]/4

# %%
## Only keep genes and transcripts with more than 0 counts
df_genes = df_genes.loc[df_genes["total_counts"] > 0].copy()
df_transcripts = df_transcripts.loc[df_transcripts["total_counts"] > 0].copy()

# %%
## Calculate percentile
df_genes['percentile'] = df_genes["total_counts"].rank(pct=True)

# %%
## Calculate Rank
df_genes['rank'] = df_genes["total_counts"].rank(ascending=False)

# %%
## See rank for PSEN1
## Respectively: ENSG00000080815
df_genes.loc[df_genes.index.str.contains("ENSG00000080815")]
# Out:
#                  cshl_356_uky_mapped_filtered_sorted  \
# ENSG00000080815                                 4784
#
#                  cshl_1271_uky_mapped_filtered_sorted  \
# ENSG00000080815                                  2803
#
#                  cshl_1291_uky_mapped_filtered_sorted  \
# ENSG00000080815                                  2121
#
#                  cshl_1304_uky_mapped_filtered_sorted  total_counts  \
# ENSG00000080815                                  2992          7916
#
#                  average_counts  percentile    rank
# ENSG00000080815          1979.0    0.918208  4220.0

# %%
## See rank for PSEN2
## Respectively: ENSG00000143801
df_genes.loc[df_genes.index.str.contains("ENSG00000143801")]
# Out:
#                  cshl_356_uky_mapped_filtered_sorted  \
# ENSG00000143801                                  281
#
#                  cshl_1271_uky_mapped_filtered_sorted  \
# ENSG00000143801                                   224
#
#                  cshl_1291_uky_mapped_filtered_sorted  \
# ENSG00000143801                                   236
#
#                  cshl_1304_uky_mapped_filtered_sorted  total_counts  \
# ENSG00000143801                                   269           729
#
#                  average_counts  percentile     rank
# ENSG00000143801          182.25    0.734481  13697.0

# %%
## See rank for BIN1
## Respectively: ENSG00000136717
df_genes.loc[df_genes.index.str.contains("ENSG00000136717")]
# Out:
#                  cshl_356_uky_mapped_filtered_sorted  \
# ENSG00000136717                                 8468
#
#                  cshl_1271_uky_mapped_filtered_sorted  \
# ENSG00000136717                                  4878
#
#                  cshl_1291_uky_mapped_filtered_sorted  \
# ENSG00000136717                                  4394
#
#                  cshl_1304_uky_mapped_filtered_sorted  total_counts  \
# ENSG00000136717                                  6222         15494
#
#                  average_counts  percentile    rank
# ENSG00000136717          3873.5    0.958959  2118.0

# %%
## Get total counts for all genes with more than 0 counts
total_counts = df_genes["total_counts"]

# %%
## Get log total counts
log_total_counts = np.log10(df_genes["total_counts"])

# %%
print("PSEN1 Log Expression:", log_total_counts["ENSG00000080815"])
print("PSEN2 Log Expression:", log_total_counts["ENSG00000143801"])
print("BIN1 Log Expression:", log_total_counts["ENSG00000136717"])
# Out:
# PSEN1 Log Expression: 3.8985057855343586
# PSEN2 Log Expression: 2.8627275283179747
# BIN1 Log Expression: 4.190163551630705

# %%
## Use ggplot colors
ggplot2_colors = ["#F8766D", "#CD9600", "#7CAE00", "#00BE67", "#00BFC4", "#00A9FF", "#C77CFF", "#FF61CC"]

# %%
## Create log plot

fig, ax = plt.subplots(figsize = (6,4))


log_total_counts.plot(kind = "hist", density = True, bins = 100, color="#F8766D", alpha=0.5) # change density to true, because KDE uses density


log_total_counts.plot(kind = "kde", color="#CD9600", alpha=1)

ax.set_xlabel("Log10 Total Counts")


ax.set_title("Histogram of Total Read Counts per Gene")

ax.axvline(3.89, alpha=1, ymax = 0.85, linestyle = ":", color="#7CAE00")
ax.axvline(2.86, alpha=1, ymax = 0.60, linestyle = ":", color="#00BE67")
ax.axvline(4.19, alpha=1, ymax = 0.60, linestyle = ":", color="#00BFC4")


ax.text(3.89 - 0.5, 0.59, "PSEN1", size = 12, alpha = 1, color="#7CAE00")
ax.text(2.86 - 1, 0.42, "PSEN2", size = 12, alpha = 1, color="#00BE67")
ax.text(4.19, 0.42, "BIN1", size = 12, alpha = 1, color="#00BFC4")



plt.show()

# %% [markdown]
# #####################################################################################################

# %%
df_transcripts.head()
# Out:
#   TXNAME           GENEID  cshl_356_uky_mapped_filtered_sorted  \
# 0   tx.1  ENSG00000078808                           638.547019
# 1   tx.2  ENSG00000008130                            86.895137
# 2   tx.3        gene.4578                            28.000000
# 3   tx.4  ENSG00000116663                            89.692718
# 4   tx.5        gene.5343                            45.000000
#
#    cshl_1271_uky_mapped_filtered_sorted  cshl_1291_uky_mapped_filtered_sorted  \
# 0                            545.271793                            570.311659
# 1                            135.226654                            157.979474
# 2                             69.000000                            162.000000
# 3                             71.295613                             43.156208
# 4                             28.000000                             51.000000
#
#    cshl_1304_uky_mapped_filtered_sorted  total_counts  average_counts
# 0                            918.306555   2672.437026      668.109257
# 1                             89.532209    469.633474      117.408369
# 2                             67.000000    326.000000       81.500000
# 3                            154.145707    358.290246       89.572562
# 4                             26.000000    150.000000       37.500000

# %%
df_transcripts.columns = ["TXNAME", "GENEID", "356_counts", "1271_counts", "1291_counts", "1304_counts",
                          "total_counts", "average_counts"]

# %%
df_t_cpm = calculate_cpm(df_transcripts)

# %%
## Look at PSEN1 expression
df_t_cpm.loc[df_t_cpm["GENEID"].str.contains("ENSG00000080815")].sort_values(by="average_CPM", ascending=False)
# Out:
#                  TXNAME           GENEID    356_counts   1271_counts  \
# 246872  ENST00000697915  ENSG00000080815  1.775841e+03  7.349193e+02
# 11623   ENST00000324501  ENSG00000080815  9.039174e+02  7.600930e+02
# 17381   ENST00000357710  ENSG00000080815  6.043688e+02  3.608003e+02
# 249114  ENST00000700268  ENSG00000080815  4.837541e+02  5.292424e+02
# 142661  ENST00000554995  ENSG00000080815  4.192818e+02  1.062449e+02
# 36996   ENST00000406768  ENSG00000080815  1.609839e+02  6.072455e+01
# 249117  ENST00000700271  ENSG00000080815  8.740405e+01  6.209986e+01
# 249220  ENST00000700404  ENSG00000080815  2.171354e+01  1.426428e+01
# 246870  ENST00000697913  ENSG00000080815  4.228589e+01  1.544296e+01
# 147327  ENST00000560005  ENSG00000080815  1.740474e+01  0.000000e+00
# 249112  ENST00000700266  ENSG00000080815  0.000000e+00  3.390872e+00
# 249156  ENST00000700312  ENSG00000080815  1.214278e+01  1.822073e+01
# 144811  ENST00000557293  ENSG00000080815  1.977600e+01  5.589702e+00
# 249205  ENST00000700389  ENSG00000080815  1.349727e+01  0.000000e+00
# 249157  ENST00000700313  ENSG00000080815  1.880403e+01  1.431062e+01
# 249199  ENST00000700376  ENSG00000080815  1.551383e+01  3.007822e+00
# 249206  ENST00000700390  ENSG00000080815  2.038211e+01  2.547318e+00
# 32237   ENST00000394157  ENSG00000080815  1.245559e+01  8.483561e+00
# 249148  ENST00000700304  ENSG00000080815  9.083851e+00  6.703058e+00
# 249204  ENST00000700388  ENSG00000080815  9.856979e+00  4.332213e+00
# 249146  ENST00000700302  ENSG00000080815  8.335555e+00  0.000000e+00
# 249167  ENST00000700323  ENSG00000080815  1.432171e+01  1.175052e+01
# 249202  ENST00000700379  ENSG00000080815  1.381095e+01  0.000000e+00
# 249152  ENST00000700308  ENSG00000080815  5.482412e+00  3.776653e+00
# 249251  ENST00000700437  ENSG00000080815  6.891432e+00  0.000000e+00
# 249155  ENST00000700311  ENSG00000080815  7.650613e+00  0.000000e+00
# 249224  ENST00000700408  ENSG00000080815  6.041889e+00  4.008410e+00
# 249115  ENST00000700269  ENSG00000080815  0.000000e+00  5.162320e-11
# 249163  ENST00000700319  ENSG00000080815  7.814292e+00  0.000000e+00
# 249161  ENST00000700317  ENSG00000080815  1.668759e+00  1.779038e+01
# 249201  ENST00000700378  ENSG00000080815  0.000000e+00  4.337298e+00
# 144488  ENST00000556951  ENSG00000080815  8.452664e+00  0.000000e+00
# 249151  ENST00000700307  ENSG00000080815  6.543415e+00  0.000000e+00
# 141853  ENST00000554131  ENSG00000080815  2.105223e+00  1.175052e+01
# 249226  ENST00000700410  ENSG00000080815  2.310164e+00  4.010185e+00
# 246869  ENST00000697912  ENSG00000080815  6.243146e+00  0.000000e+00
# 249246  ENST00000700432  ENSG00000080815  4.607127e+00  1.002546e+00
# 249225  ENST00000700409  ENSG00000080815  0.000000e+00  4.008410e+00
# 249166  ENST00000700322  ENSG00000080815  0.000000e+00  3.312861e+00
# 249150  ENST00000700306  ENSG00000080815  3.322523e+00  0.000000e+00
# 141355  ENST00000553599  ENSG00000080815  1.542995e-09  4.984551e+00
# 246871  ENST00000697914  ENSG00000080815  7.024940e+00  0.000000e+00
# 249250  ENST00000700436  ENSG00000080815  0.000000e+00  0.000000e+00
# 249149  ENST00000700305  ENSG00000080815  1.830804e+00  3.382067e+00
# 249159  ENST00000700315  ENSG00000080815  0.000000e+00  3.467479e+00
# 249160  ENST00000700316  ENSG00000080815  5.347705e+00  0.000000e+00
# 249118  ENST00000700272  ENSG00000080815  0.000000e+00  6.703058e+00
# 249223  ENST00000700407  ENSG00000080815  2.004272e+00  0.000000e+00
# 249245  ENST00000700431  ENSG00000080815  4.617039e-05  0.000000e+00
# 32242   ENST00000394164  ENSG00000080815  0.000000e+00  2.505799e+00
# 249249  ENST00000700435  ENSG00000080815  0.000000e+00  0.000000e+00
# 141594  ENST00000553855  ENSG00000080815  0.000000e+00  0.000000e+00
# 143673  ENST00000556066  ENSG00000080815  1.697107e+00  0.000000e+00
# 143036  ENST00000555386  ENSG00000080815  1.139458e+00  0.000000e+00
# 249119  ENST00000700273  ENSG00000080815  0.000000e+00  1.021916e-08
# 249198  ENST00000700375  ENSG00000080815  1.726368e+00  0.000000e+00
# 249197  ENST00000700374  ENSG00000080815  0.000000e+00  2.130170e+00
# 249113  ENST00000700267  ENSG00000080815  1.726368e+00  0.000000e+00
# 249164  ENST00000700320  ENSG00000080815  1.932611e+00  0.000000e+00
# 249147  ENST00000700303  ENSG00000080815  1.836456e+00  0.000000e+00
# 249158  ENST00000700314  ENSG00000080815  3.459128e+00  0.000000e+00
# 144570  ENST00000557037  ENSG00000080815  0.000000e+00  2.005093e+00
# 249207  ENST00000700391  ENSG00000080815  0.000000e+00  7.455848e-05
# 249168  ENST00000700324  ENSG00000080815  0.000000e+00  8.513115e-09
# 249111  ENST00000700265  ENSG00000080815  0.000000e+00  1.656430e+00
# 249247  ENST00000700433  ENSG00000080815  2.054725e-01  0.000000e+00
# 249248  ENST00000700434  ENSG00000080815  0.000000e+00  0.000000e+00
# 249153  ENST00000700309  ENSG00000080815  0.000000e+00  9.977756e-06
# 249116  ENST00000700270  ENSG00000080815  0.000000e+00  0.000000e+00
#
#          1291_counts   1304_counts  total_counts  average_counts  average_CPM
# 246872  5.515858e+02  1.268227e+01       3075.03    7.687570e+02         9.19
# 11623   6.019366e+02  8.030073e+02       3068.95    7.672386e+02         9.18
# 17381   2.330642e+02  5.483011e+02       1746.53    4.366336e+02         5.22
# 249114  2.268210e+02  4.969544e+02       1736.77    4.341930e+02         5.19
# 142661  9.796424e+01  2.766957e+02        900.19    2.250467e+02         2.69
# 36996   7.620222e+01  2.129963e+02        510.91    1.277267e+02         1.53
# 249117  9.939457e+01  1.016605e+02        350.56    8.763974e+01         1.05
# 249220  5.140421e+01  1.998045e+02        287.19    7.179664e+01         0.86
# 246870  2.473945e+01  3.960419e+01        122.07    3.051812e+01         0.37
# 147327  1.412971e+01  2.651204e+01         58.05    1.451162e+01         0.17
# 249112  2.762969e+01  2.553526e+01         56.56    1.413896e+01         0.17
# 249156  1.829496e+01  9.256276e+00         57.91    1.447869e+01         0.17
# 144811  1.896822e+00  2.425677e+01         51.52    1.287982e+01         0.15
# 249205  2.203369e+01  1.599990e+01         51.53    1.288271e+01         0.15
# 249157  0.000000e+00  8.908072e+00         42.02    1.050568e+01         0.13
# 249199  1.100000e+01  6.679154e+00         36.20    9.050201e+00         0.11
# 249206  1.855482e+00  7.185544e+00         31.97    7.992614e+00         0.10
# 32237   7.131061e+00  4.433898e-01         28.51    7.128401e+00         0.09
# 249148  0.000000e+00  1.281894e+01         28.61    7.151461e+00         0.09
# 249204  1.018723e+00  1.138330e+01         26.59    6.647804e+00         0.08
# 249146  6.456200e-12  1.875880e+01         27.09    6.773589e+00         0.08
# 249167  0.000000e+00  0.000000e+00         26.07    6.518058e+00         0.08
# 249202  8.081196e+00  0.000000e+00         21.89    5.473036e+00         0.07
# 249152  3.326535e+00  9.600508e+00         22.19    5.546527e+00         0.07
# 249251  0.000000e+00  1.289741e+01         19.79    4.947211e+00         0.06
# 249155  1.181284e+01  0.000000e+00         19.46    4.865864e+00         0.06
# 249224  4.999628e+00  5.044642e+00         20.09    5.023642e+00         0.06
# 249115  0.000000e+00  1.910899e+01         19.11    4.777246e+00         0.06
# 249163  0.000000e+00  1.171622e+01         19.53    4.882628e+00         0.06
# 249161  0.000000e+00  0.000000e+00         19.46    4.864786e+00         0.06
# 249201  0.000000e+00  1.405685e+01         18.39    4.598538e+00         0.05
# 144488  3.792686e+00  4.618948e+00         16.86    4.216074e+00         0.05
# 249151  0.000000e+00  8.097466e+00         14.64    3.660220e+00         0.04
# 141853  0.000000e+00  0.000000e+00         13.86    3.463936e+00         0.04
# 249226  4.000000e+00  3.010326e+00         13.33    3.332669e+00         0.04
# 246869  1.026101e-04  5.350551e+00         11.59    2.898450e+00         0.03
# 249246  2.022847e+00  2.279416e+00          9.91    2.477984e+00         0.03
# 249225  5.043864e+00  0.000000e+00          9.05    2.263068e+00         0.03
# 249166  0.000000e+00  5.325823e+00          8.64    2.159671e+00         0.03
# 249150  0.000000e+00  4.368485e+00          7.69    1.922752e+00         0.02
# 141355  0.000000e+00  1.718620e+00          6.70    1.675793e+00         0.02
# 246871  0.000000e+00  1.032252e+00          8.06    2.014298e+00         0.02
# 249250  0.000000e+00  6.889365e+00          6.89    1.722341e+00         0.02
# 249149  0.000000e+00  3.483640e-11          5.21    1.303218e+00         0.02
# 249159  0.000000e+00  2.017320e+00          5.48    1.371200e+00         0.02
# 249160  0.000000e+00  0.000000e+00          5.35    1.336926e+00         0.02
# 249118  0.000000e+00  0.000000e+00          6.70    1.675765e+00         0.02
# 249223  1.924656e+00  2.007036e+00          5.94    1.483991e+00         0.02
# 249245  0.000000e+00  2.670175e+00          2.67    6.675553e-01         0.01
# 32242   0.000000e+00  2.065351e+00          4.57    1.142788e+00         0.01
# 249249  2.999957e+00  0.000000e+00          3.00    7.499893e-01         0.01
# 141594  3.000000e+00  0.000000e+00          3.00    7.500000e-01         0.01
# 143673  0.000000e+00  0.000000e+00          1.70    4.242767e-01         0.01
# 143036  0.000000e+00  1.079778e+00          2.22    5.548090e-01         0.01
# 249119  0.000000e+00  2.510472e+00          2.51    6.276181e-01         0.01
# 249198  0.000000e+00  0.000000e+00          1.73    4.315921e-01         0.01
# 249197  0.000000e+00  0.000000e+00          2.13    5.325424e-01         0.01
# 249113  0.000000e+00  3.083388e+00          4.81    1.202439e+00         0.01
# 249164  1.893139e+00  0.000000e+00          3.83    9.564374e-01         0.01
# 249147  0.000000e+00  0.000000e+00          1.84    4.591139e-01         0.01
# 249158  0.000000e+00  0.000000e+00          3.46    8.647820e-01         0.01
# 144570  0.000000e+00  2.006884e+00          4.01    1.002994e+00         0.01
# 249207  0.000000e+00  1.072031e-04          0.00    4.544039e-05         0.00
# 249168  0.000000e+00  0.000000e+00          0.00    2.128279e-09         0.00
# 249111  0.000000e+00  0.000000e+00          1.66    4.141076e-01         0.00
# 249247  0.000000e+00  0.000000e+00          0.21    5.136811e-02         0.00
# 249248  1.474343e-09  0.000000e+00          0.00    3.685857e-10         0.00
# 249153  0.000000e+00  0.000000e+00          0.00    2.494439e-06         0.00
# 249116  1.167090e-04  0.000000e+00          0.00    2.917725e-05         0.00

# %%
## Look at PSEN2 expression
df_t_cpm.loc[df_t_cpm["GENEID"].str.contains("ENSG00000143801")]
# Out:
#                  TXNAME           GENEID    356_counts  1271_counts  \
# 20844   ENST00000366782  ENSG00000143801  0.000000e+00     0.000000
# 20845   ENST00000366783  ENSG00000143801  4.355880e+01    87.170810
# 45813   ENST00000422240  ENSG00000143801  1.982856e-07     0.000005
# 78478   ENST00000471728  ENSG00000143801  0.000000e+00     6.858914
# 78809   ENST00000472139  ENSG00000143801  0.000000e+00     3.000000
# 89644   ENST00000485677  ENSG00000143801  1.900000e+01     0.000000
# 97428   ENST00000495488  ENSG00000143801  0.000000e+00     0.000000
# 117264  ENST00000521431  ENSG00000143801  2.330891e+00     5.000000
# 227902  ENST00000676467  ENSG00000143801  2.165212e+01     0.000000
# 228051  ENST00000676616  ENSG00000143801  3.000000e+01     3.000000
# 228272  ENST00000676840  ENSG00000143801  0.000000e+00     0.000000
# 228319  ENST00000676888  ENSG00000143801  4.312641e-01     1.554473
# 228338  ENST00000676907  ENSG00000143801  2.748804e+00     0.000000
# 228376  ENST00000676945  ENSG00000143801  4.387066e+00     7.165440
# 228494  ENST00000677065  ENSG00000143801  0.000000e+00     5.000000
# 228839  ENST00000677414  ENSG00000143801  0.000000e+00    26.386018
# 228953  ENST00000677529  ENSG00000143801  1.226554e+00     6.779666
# 229019  ENST00000677596  ENSG00000143801  4.300000e-15     0.000000
# 229022  ENST00000677599  ENSG00000143801  1.503765e+01    15.354514
# 229168  ENST00000677748  ENSG00000143801  6.010113e+01     1.951382
# 229299  ENST00000677880  ENSG00000143801  1.256718e+01    26.000000
# 229439  ENST00000678021  ENSG00000143801  9.076916e+00    12.108834
# 229649  ENST00000678233  ENSG00000143801  5.870022e+00     8.504505
# 229736  ENST00000678320  ENSG00000143801  7.677366e+00     6.141806
# 230065  ENST00000678655  ENSG00000143801  0.000000e+00     0.000000
# 230184  ENST00000678776  ENSG00000143801  6.060739e-01     0.000000
# 230228  ENST00000678820  ENSG00000143801  0.000000e+00     0.000000
# 230243  ENST00000678835  ENSG00000143801  0.000000e+00     1.023634
# 230495  ENST00000679088  ENSG00000143801  4.472816e+01     1.000000
# 230505  ENST00000679098  ENSG00000143801  2.930767e-06     0.000000
#
#         1291_counts  1304_counts  total_counts  average_counts  average_CPM
# 20844     10.000000    20.985003         30.99        7.746251         0.09
# 20845     31.631619    50.923319        213.28       53.321138         0.64
# 45813      7.093389    21.753994         28.85        7.211847         0.09
# 78478     18.792185     2.000000         27.65        6.912775         0.08
# 78809      0.000000     0.000000          3.00        0.750000         0.01
# 89644     14.000000    11.000000         44.00       11.000000         0.13
# 97428      2.000000     0.000000          2.00        0.500000         0.01
# 117264     0.163737     4.213229         11.71        2.926964         0.04
# 227902     3.836263     0.000000         25.49        6.372097         0.08
# 228051    23.000000    26.000000         82.00       20.500000         0.25
# 228272     0.000000     1.059973          1.06        0.264993         0.00
# 228319     0.000000     0.000000          1.99        0.496434         0.01
# 228338     0.000000     0.000007          2.75        0.687203         0.01
# 228376     7.784630     1.059973         20.40        5.099277         0.06
# 228494     0.000000     0.000000          5.00        1.250000         0.01
# 228839     7.000000    21.000000         54.39       13.596504         0.16
# 228953     0.000000     1.578084          9.58        2.396076         0.03
# 229019     0.000000     9.999993         10.00        2.499998         0.03
# 229022    42.072753    31.583580        104.05       26.012124         0.31
# 229168     1.671504     1.578084         65.30       16.325524         0.20
# 229299    18.800404    33.469962         90.84       22.709387         0.27
# 229439     2.224180     3.042724         26.45        6.613163         0.08
# 229649     3.145777     1.276081         18.80        4.699096         0.06
# 229736    11.869407     9.539758         35.23        8.807084         0.11
# 230065     0.000006     0.000000          0.00        0.000001         0.00
# 230184     0.000000     8.786771          9.39        2.348211         0.03
# 230228     2.533664     0.000000          2.53        0.633416         0.01
# 230243     2.865828     1.059973          4.95        1.237359         0.01
# 230495    23.224028     7.089493         76.04       19.010419         0.23
# 230505     2.290625     0.000000          2.29        0.572657         0.01

# %%
## Look at BIN1 expression
df_t_cpm.loc[df_t_cpm["GENEID"].str.contains("ENSG00000136717")]
# Out:
#                 TXNAME           GENEID   356_counts  1271_counts  \
# 3885   ENST00000259238  ENSG00000136717   979.058899     0.000217
# 10544  ENST00000316724  ENSG00000136717   740.863353   444.978862
# 15446  ENST00000346226  ENSG00000136717   176.457424    15.207230
# 15709  ENST00000348750  ENSG00000136717  1494.109420  2067.098795
# 15985  ENST00000351659  ENSG00000136717   191.687675    80.266351
# 16100  ENST00000352848  ENSG00000136717   655.546466  1397.234182
# 17464  ENST00000357970  ENSG00000136717    74.772769    15.475234
# 25811  ENST00000376113  ENSG00000136717  2884.471192   432.753215
# 31648  ENST00000393040  ENSG00000136717   523.167432   247.432733
# 31649  ENST00000393041  ENSG00000136717    91.647175     0.000000
# 37984  ENST00000409400  ENSG00000136717   522.708746    95.520278
# 71430  ENST00000462958  ENSG00000136717   123.231899    75.947665
# 73975  ENST00000466111  ENSG00000136717     1.737745     0.000000
# 88488  ENST00000484253  ENSG00000136717     8.539806     6.085239
#
#        1291_counts  1304_counts  total_counts  average_counts  average_CPM
# 3885      0.000270   203.524517       1182.58      295.645976         3.54
# 10544   312.163999  1244.410584       2742.42      685.604199         8.20
# 15446    22.019908   114.971281        328.66       82.163961         0.98
# 15709  2711.494717  1047.272649       7319.98     1829.993895        21.89
# 15985    93.604521    98.583823        464.14      116.035593         1.39
# 16100   586.618613   161.455352       2800.85      700.213653         8.37
# 17464    46.216634    39.063321        175.53       43.881990         0.52
# 25811   146.996892  2172.995779       5637.22     1409.304269        16.86
# 31648   239.172323   244.759561       1254.53      313.633012         3.75
# 31649    21.247658   226.243651        339.14       84.784621         1.01
# 37984    86.591842   466.021467       1170.84      292.710583         3.50
# 71430   115.381702   186.385499        500.95      125.236691         1.50
# 73975     2.321441     2.111285          6.17        1.542618         0.02
# 88488    10.169480    14.201230         39.00        9.748939         0.12
